# %% [markdown]
# # Data Prep
#
# This notebook contains the code required for preparing, cleaning, and exploring the BikeShare demand dataset.

# %% [markdown]
# ## Imports

# %%
import os
import io
import json
from dateutil.parser import parse
import pandas as pd
import numpy as np
import requests
import sys
from datetime import datetime, timedelta
from dateutil import rrule
import matplotlib.pyplot as plt
import holidays
import seaborn as sns

# %% [markdown]
# ## Functions

# %%
dateparse = lambda x: datetime.strptime(x, '%y-%m-%d %H:%M')
dateparse_timezone = lambda x: datetime.strptime(x[:-4], '%Y-%m-%d %H:%M:%S')

def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +timedelta(hours=t.minute//30))
    
def getHourlyData(stationID, year, month):
    base_url = "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?"
    query_url = "format=csv&stationID={}&Year={}&Month={}&timeframe=1".format(stationID, year, month)
    api_endpoint = base_url + query_url
    return pd.read_csv(api_endpoint, skiprows=16)

def getData(stationID, year, month):
    base_url = "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?"
    query_url = "format=csv&stationID={}&Year={}&Month={}&timeframe=1".format(stationID, year, month)
    api_endpoint = base_url + query_url
    return pd.read_csv(api_endpoint, skiprows=0)

# %% [markdown]
# ## Data Source: Weather Data from GC

# %% [markdown]
# ### Batch import weather data

# %%
stationID = 48549

start_date = datetime.strptime('Jan2020', '%b%Y')
end_date = datetime.strptime('Feb2022', '%b%Y')
data_range = [dt for dt in rrule.rrule(rrule.MONTHLY, dtstart=start_date, until=end_date)]

frames = []
for dt in data_range:
    df = getData(stationID, dt.year, dt.month)
    frames.append(df)
    
weather_data = pd.concat(frames)

# %%
weather_data.shape
# Out:
# (18960, 30)

# %% [markdown]
# ### Clean-up Weather Data
#
#
# 1.   Drop unwanted cols
# 2.   Fix data type(s)
# 3.   Imputation

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18960 entries, 0 to 671
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Longitude (x)        18960 non-null  float64
#  1   Latitude (y)         18960 non-null  float64
#  2   Station Name         18960 non-null  object
#  3   Climate ID           18960 non-null  int64
#  4   Date/Time (LST)      18960 non-null  object
#  5   Year                 18960 non-null  int64
#  6   Month                18960 non-null  int64
#  7   Day                  18960 non-null  int64
#  8   Time (LST)           18960 non-null  object
#  9   Temp (°C)            18921 non-null  float64
#  10  Temp Flag            18 non-null     object
#  11  Dew Point Temp (°C)  18896 non-null  float64
#  12  Dew Point Temp Flag  44 non-null     object
#  13  Rel Hum (%)          18906 non-null  float64
#  14  Rel Hum Flag         34 non-null     object
#  15  Precip. Amount (mm)  18940 non-null  float64
#  16  Precip. Amount Flag  0 non-null      float64
#  17  Wind Dir (10s deg)   18024 non-null  float64
#  18  Wind Dir Flag        507 non-null    object
#  19  Wind Spd (km/h)      18925 non-null  float64
#  20  Wind Spd Flag        15 non-null     object
#  21  Visibility (km)      18928 non-null  float64
#  22  Visibility Flag      12 non-null     object
#  23  Stn Press (kPa)      18922 non-null  float64
#  24  Stn Press Flag       18 non-null     object
#  25  Hmdx                 3026 non-null   float64
#  26  Hmdx Flag            0 non-null      float64
#  27  Wind Chill           3608 non-null   float64
#  28  Wind Chill Flag      0 non-null      float64
#  29  Weather              2704 non-null   object
# dtypes: float64(15), int64(4), object(11)
# memory usage: 4.5+ MB

# %%
weather_data.iloc[1,:]
# Out:
# Longitude (x)                        -79.4
# Latitude (y)                         43.63
# Station Name           TORONTO CITY CENTRE
# Climate ID                         6158359
# Date/Time (LST)           2020-01-01 01:00
# Year                                  2020
# Month                                    1
# Day                                      1
# Time (LST)                           01:00
# Temp (°C)                              0.1
# Temp Flag                              NaN
# Dew Point Temp (°C)                   -4.0
# Dew Point Temp Flag                    NaN
# Rel Hum (%)                           74.0
# Rel Hum Flag                           NaN
# Precip. Amount (mm)                    0.0
# Precip. Amount Flag                    NaN
# Wind Dir (10s deg)                    25.0
# Wind Dir Flag                          NaN
# Wind Spd (km/h)                       34.0
# Wind Spd Flag                          NaN
# Visibility (km)                       16.1
# Visibility Flag                        NaN
# Stn Press (kPa)                      99.33
# Stn Press Flag                         NaN
# Hmdx                                   NaN
# Hmdx Flag                              NaN
# Wind Chill                             NaN
# Wind Chill Flag                        NaN
# Weather                                NaN
# Name: 1, dtype: object

# %%
weather_data.columns
# Out:
# Index(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID',
#        'Date/Time (LST)', 'Year', 'Month', 'Day', 'Time (LST)', 'Temp (°C)',
#        'Temp Flag', 'Dew Point Temp (°C)', 'Dew Point Temp Flag',
#        'Rel Hum (%)', 'Rel Hum Flag', 'Precip. Amount (mm)',
#        'Precip. Amount Flag', 'Wind Dir (10s deg)', 'Wind Dir Flag',
#        'Wind Spd (km/h)', 'Wind Spd Flag', 'Visibility (km)',
#        'Visibility Flag', 'Stn Press (kPa)', 'Stn Press Flag', 'Hmdx',
#        'Hmdx Flag', 'Wind Chill', 'Wind Chill Flag', 'Weather'],
#       dtype='object')

# %%
cols_to_keep = ['Date/Time (LST)','Temp (°C)', 'Precip. Amount (mm)','Wind Spd (km/h)','Wind Dir (10s deg)','Visibility (km)','Weather']

# %%
weather_data_clean = weather_data[cols_to_keep]

# %%
weather_data_clean['Date/Time (LST)'] = weather_data_clean['Date/Time (LST)'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
weather_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18960 entries, 0 to 671
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date/Time (LST)      18960 non-null  datetime64[ns]
#  1   Temp (°C)            18921 non-null  float64
#  2   Precip. Amount (mm)  18940 non-null  float64
#  3   Wind Spd (km/h)      18925 non-null  float64
#  4   Wind Dir (10s deg)   18024 non-null  float64
#  5   Visibility (km)      18928 non-null  float64
#  6   Weather              2704 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.2+ MB

# %%
# Temperature: missing value is filled by last valid observation since data is organized chronologically
weather_data_clean['Temp (°C)']=weather_data_clean['Temp (°C)'].fillna(method='ffill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Precipitation: missing value is filled by 0 - no precipitation
weather_data_clean['Precip. Amount (mm)']=weather_data_clean['Precip. Amount (mm)'].fillna(0.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
weather_data_clean['Wind Spd (km/h)']=weather_data_clean['Wind Spd (km/h)'].fillna(method='ffill')
weather_data_clean['Wind Dir (10s deg)']=weather_data_clean['Wind Dir (10s deg)'].fillna(method='ffill')
weather_data_clean['Visibility (km)']=weather_data_clean['Visibility (km)'].fillna(method='ffill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
weather_data_clean['Weather'] = weather_data_clean['Weather'].fillna('Other')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
weather_data_clean.iloc[319:327]['Wind Spd (km/h)']
# Out:
#         Date/Time (LST)  Temp (°C)  Precip. Amount (mm)  Wind Spd (km/h)  \
# 319 2020-01-14 07:00:00        1.3                  0.0             28.0
# 320 2020-01-14 08:00:00        1.6                  0.0              NaN
# 321 2020-01-14 09:00:00        2.2                  0.0             22.0
# 322 2020-01-14 10:00:00        2.3                  0.0             24.0
# 323 2020-01-14 11:00:00        2.3                  0.0              NaN
# 324 2020-01-14 12:00:00        2.3                  0.0             26.0
# 325 2020-01-14 13:00:00        2.3                  0.0             26.0
# 326 2020-01-14 14:00:00        1.3                  0.0              NaN
#
#      Wind Dir (10s deg)  Visibility (km) Weather
# 319                 9.0             16.1     NaN
# 320                 NaN             16.1     NaN
# 321                 9.0             16.1     NaN
# 322                10.0             16.1     NaN
# 323                 NaN             16.1     NaN
# 324                 8.0             16.1     NaN
# 325                 7.0              NaN     NaN
# 326                 NaN              9.7     NaN

# %%
weather_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18960 entries, 0 to 671
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date/Time (LST)      18960 non-null  datetime64[ns]
#  1   Temp (°C)            18960 non-null  float64
#  2   Precip. Amount (mm)  18960 non-null  float64
#  3   Wind Spd (km/h)      18960 non-null  float64
#  4   Wind Dir (10s deg)   18960 non-null  float64
#  5   Visibility (km)      18960 non-null  float64
#  6   Weather              18960 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Add Features from Weather data

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100001 entries, 0 to 100000
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date_time_local      100001 non-null  datetime64[ns]
#  1   unixtime             100001 non-null  int64
#  2   pressure_station     99970 non-null   float64
#  3   pressure_sea         99970 non-null   float64
#  4   wind_dir             77579 non-null   object
#  5   wind_dir_10s         99135 non-null   float64
#  6   wind_speed           99972 non-null   float64
#  7   wind_gust            17794 non-null   float64
#  8   relative_humidity    99952 non-null   float64
#  9   dew_point            99957 non-null   float64
#  10  temperature          99965 non-null   float64
#  11  windchill            22911 non-null   float64
#  12  humidex              16372 non-null   float64
#  13  visibility           99973 non-null   float64
#  14  health_index         94471 non-null   float64
#  15  cloud_cover_4        0 non-null       float64
#  16  cloud_cover_8        72731 non-null   float64
#  17  cloud_cover_10       5659 non-null    float64
#  18  solar_radiation      0 non-null       float64
#  19  max_air_temp_pst1hr  73328 non-null   float64
#  20  min_air_temp_pst1hr  73330 non-null   float64
# dtypes: datetime64[ns](1), float64(18), int64(1), object(1)
# memory usage: 16.0+ MB

# %%
cols_to_add = ['date_time_local','wind_speed', 'temperature','windchill','visibility']
df_combined = pd.merge(df, weather[cols_to_add], how='left',left_on='Rounded_Start_Time', right_on='date_time_local')

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 945169 entries, 0 to 945168
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Trip Id              945169 non-null  int64
#  1   Trip  Duration       945169 non-null  int64
#  2   Start Station Id     945169 non-null  int64
#  3   Start Time           945169 non-null  datetime64[ns]
#  4   Start Station Name   945169 non-null  object
#  5   End Station Id       945169 non-null  int64
#  6   End Time             945169 non-null  object
#  7   End Station Name     945169 non-null  object
#  8   Bike Id              945169 non-null  int64
#  9   User Type            945169 non-null  object
#  10  orig_coords          945169 non-null  object
#  11  dest_coords          945169 non-null  object
#  12  Origin Address       945169 non-null  object
#  13  Destination Address  945169 non-null  object
#  14  Duration (s)         945169 non-null  int64
#  15  Distance (m)         945169 non-null  int64
#  16  Rounded_Start_Time   945169 non-null  datetime64[ns]
#  17  date_time_local      945169 non-null  datetime64[ns]
#  18  wind_speed           945169 non-null  float64
#  19  temperature          945156 non-null  float64
#  20  windchill            103435 non-null  float64
#  21  visibility           945169 non-null  float64
# dtypes: datetime64[ns](3), float64(4), int64(7), object(8)
# memory usage: 165.9+ MB

# %%
df_combined[df_combined['date_time_local'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Trip Id, Trip  Duration, Start Station Id, Start Time, Start Station Name, End Station Id, End Time, End Station Name, Bike Id, User Type, orig_coords, dest_coords, Origin Address, Destination Address, Duration (s), Distance (m), Rounded_Start_Time, date_time_local, wind_speed, temperature, windchill, visibility]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Data Source: Toronto Bike Share Data

# %%
data_path = "../data/01_trip_data_2020-01_2022-02.csv"
df_trip_data = pd.read_csv(data_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2,5,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_trip_data.head()
# Out:
#    Trip Id  Trip  Duration Start Station Id        Start Time  \
# 0  7334128             648             7003  01/01/2020 00:08
# 1  7334129             419             7007  01/01/2020 00:10
# 2  7334130             566             7113  01/01/2020 00:13
# 3  7334131            1274             7333  01/01/2020 00:17
# 4  7334132             906             7009  01/01/2020 00:19
#
#              Start Station Name End Station Id          End Time  \
# 0      Madison Ave / Bloor St W         7271.0  01/01/2020 00:19
# 1         College St / Huron St         7163.0  01/01/2020 00:17
# 2  Parliament St / Aberdeen Ave         7108.0  01/01/2020 00:22
# 3       King St E / Victoria St         7311.0  01/01/2020 00:38
# 4         King St E / Jarvis St         7004.0  01/01/2020 00:34
#
#                   End Station Name Bike Id      User Type
# 0  Yonge St / Alexander St - SMART    3104  Annual Member
# 1               Yonge St / Wood St    2126  Annual Member
# 2           Front St E / Cherry St    4425  Annual Member
# 3      Sherbourne St / Isabella St    4233  Annual Member
# 4          University Ave / Elm St    2341  Casual Member

# %%
df_trip_data.tail()
# Out:
#           Trip Id  Trip  Duration Start Station Id        Start Time  \
# 6610260  14964896             139             7055  02/28/2022 23:56
# 6610261  14964899            1098             7143  02/28/2022 23:57
# 6610262  14964900             459             7450  02/28/2022 23:57
# 6610263  14964903             410             7473  02/28/2022 23:58
# 6610264  14964904             743             7178  02/28/2022 23:59
#
#                    Start Station Name End Station Id          End Time  \
# 6610260        Jarvis St / Carlton St         7443.0  02/28/2022 23:58
# 6610261      Kendal Ave / Bernard Ave         7143.0  03/01/2022 00:15
# 6610262     Carlaw Ave / Danforth Ave         7340.0  03/01/2022 00:05
# 6610263  Adelaide St W / Strachan Ave         7017.0  03/01/2022 00:05
# 6610264        Dundas St W / Edna Ave         7496.0  03/01/2022 00:12
#
#                               End Station Name Bike Id      User Type
# 6610260                Dundas St E / George St    4354  Annual Member
# 6610261               Kendal Ave / Bernard Ave    5575  Annual Member
# 6610262                Blake St / Boultbee Ave    4169  Annual Member
# 6610263              Widmer St / Adelaide St W    4117  Annual Member
# 6610264  Sunnyside Ave / The Queensway - SMART    2232  Annual Member

# %% [markdown]
# ### Fix Start Station Id Type
#
# Data type of station ID in certain cells was float. Coverted all to string and replaced '.0'

# %%
#Data type of station ID in certain cells was float. Converted all to string and replaced '.0'
df_trip_data['Start Station Id'] = df_trip_data['Start Station Id'].astype(str)
df_trip_data['Start Station Id'] = df_trip_data['Start Station Id'].map(lambda x: x.replace('.0',''))
df_trip_data['Start Station Id']
# Out:
# 0          7003
# 1          7007
# 2          7113
# 3          7333
# 4          7009
#            ...
# 6647662    7065
# 6647663    7292
# 6647664    7065
# 6647665    7233
# 6647666    7057
# Name: Start Station Id, Length: 6647667, dtype: object

# %%
#Data type of station ID in certain cells was float. Coverted all to string and replaced '.0'
df_trip_data['End Station Id'] = df_trip_data['End Station Id'].astype(str)
df_trip_data['End Station Id'] = df_trip_data['End Station Id'].map(lambda x: x.replace('.0',''))
df_trip_data['End Station Id']
# Out:
# 0          7271
# 1          7163
# 2          7108
# 3          7311
# 4          7004
#            ...
# 6647662    7472
# 6647663    7076
# 6647664    7472
# 6647665    7569
# 6647666    7383
# Name: End Station Id, Length: 6647667, dtype: object

# %%
df_trip_data.describe(include = 'all')
# Out:
#        Start Station Id        Start Time       Start Station Name  \
# count           6647667           6647667                  6641158
# unique              631            839990                      737
# top                7076  05/15/2021 13:38  York St / Queens Quay W
# freq              62667               100                    62667
# mean                NaN               NaN                      NaN
# std                 NaN               NaN                      NaN
# min                 NaN               NaN                      NaN
# 25%                 NaN               NaN                      NaN
# 50%                 NaN               NaN                      NaN
# 75%                 NaN               NaN                      NaN
# max                 NaN               NaN                      NaN
#
#        End Station Id          End Time         End Station Name  \
# count         6647667           6647667                  6637372
# unique            633            839569                      741
# top              7076  05/16/2021 16:13  York St / Queens Quay W
# freq            70088                78                    70088
# mean              NaN               NaN                      NaN
# std               NaN               NaN                      NaN
# min               NaN               NaN                      NaN
# 25%               NaN               NaN                      NaN
# 50%               NaN               NaN                      NaN
# 75%               NaN               NaN                      NaN
# max               NaN               NaN                      NaN
#
#              Bike Id      User Type
# count   6.647594e+06        6647667
# unique           NaN              2
# top              NaN  Annual Member
# freq             NaN        4125658
# mean    3.739091e+03            NaN
# std     1.927957e+03            NaN
# min     1.400000e+01            NaN
# 25%     2.208000e+03            NaN
# 50%     3.961000e+03            NaN
# 75%     5.383000e+03            NaN
# max     6.936000e+03            NaN

# %% [markdown]
# ### Parse Time Columns to Datetime Type

# %%
dateparse = lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M')
df_trip_data['Start Time Fixed'] = df_trip_data['Start Time'].apply(dateparse)
df_trip_data['End Time Fixed'] = df_trip_data['End Time'].apply(dateparse)

# %%
df_trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6647667 entries, 0 to 6647666
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip  Duration      float64
#  1   Start Station Id    object
#  2   Start Time          object
#  3   Start Station Name  object
#  4   End Station Id      object
#  5   End Time            object
#  6   End Station Name    object
#  7   Bike Id             float64
#  8   User Type           object
#  9   Start Time Fixed    datetime64[ns]
#  10  End Time Fixed      datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(7)
# memory usage: 557.9+ MB

# %%
df_trip_data.isna().sum()
# Out:
# Trip  Duration          247
# Start Station Id          0
# Start Time                0
# Start Station Name     6509
# End Station Id            0
# End Time                  0
# End Station Name      10295
# Bike Id                  73
# User Type                 0
# Start Time Fixed          0
# End Time Fixed            0
# dtype: int64

# %%
df_trip_data[df_trip_data['End Station Id'].isna()]
# Out:
# Empty DataFrame
# Columns: [Trip  Duration, Start Station Id, Start Time, Start Station Name, End Station Id, End Time, End Station Name, Bike Id, User Type, Start Time Fixed, End Time Fixed]
# Index: []

# %% [markdown]
# ### Filter out erroneous trips
#
# Trips less than 2 mins in duration or having same station as start/end are filtered out

# %%
# Dropping na entries - End Station Id is null or Trip Duration 0 - assume Bikes were taken out of rotation
df_trip_data = df_trip_data.dropna()
df_trip_data = df_trip_data[(df_trip_data['Trip  Duration'] > 120) & (df_trip_data['Start Station Id'] != df_trip_data['End Station Id'])]

# %%
# Confirm all bad trips are removed
df_trip_data[~((df_trip_data['Trip  Duration'] > 120) & (df_trip_data['Start Station Id'] != df_trip_data['End Station Id']))]
# Out:
# Empty DataFrame
# Columns: [Trip  Duration, Start Station Id, Start Time, Start Station Name, End Station Id, End Time, End Station Name, Bike Id, User Type, Start Time Fixed, End Time Fixed]
# Index: []

# %%
df_trip_data
# Out:
#          Trip  Duration Start Station Id        Start Time  \
# 0                 648.0             7003  01/01/2020 00:08
# 1                 419.0             7007  01/01/2020 00:10
# 2                 566.0             7113  01/01/2020 00:13
# 3                1274.0             7333  01/01/2020 00:17
# 4                 906.0             7009  01/01/2020 00:19
# ...                 ...              ...               ...
# 6647662           355.0             7065  12/31/2021 23:56
# 6647663           770.0             7292  12/31/2021 23:56
# 6647664           372.0             7065  12/31/2021 23:56
# 6647665           762.0             7233  12/31/2021 23:56
# 6647666          1307.0             7057  12/31/2021 23:59
#
#                       Start Station Name End Station Id          End Time  \
# 0               Madison Ave / Bloor St W           7271  01/01/2020 00:19
# 1                  College St / Huron St           7163  01/01/2020 00:17
# 2           Parliament St / Aberdeen Ave           7108  01/01/2020 00:22
# 3                King St E / Victoria St           7311  01/01/2020 00:38
# 4                  King St E / Jarvis St           7004  01/01/2020 00:34
# ...                                  ...            ...               ...
# 6647662      Dundas St E / Parliament St           7472  01/01/2022 00:02
# 6647663    Granby St / Church St - SMART           7076  01/01/2022 00:09
# 6647664      Dundas St E / Parliament St           7472  01/01/2022 00:02
# 6647665         King / Cowan Ave - SMART           7569  01/01/2022 00:08
# 6647666  Simcoe St / Wellington St South           7383  01/01/2022 00:21
#
#                         End Station Name  Bike Id      User Type  \
# 0        Yonge St / Alexander St - SMART   3104.0  Annual Member
# 1                     Yonge St / Wood St   2126.0  Annual Member
# 2                 Front St E / Cherry St   4425.0  Annual Member
# 3            Sherbourne St / Isabella St   4233.0  Annual Member
# 4                University Ave / Elm St   2341.0  Casual Member
# ...                                  ...      ...            ...
# 6647662        Dundas St E / Victoria St   4574.0  Casual Member
# 6647663          York St / Queens Quay W   5879.0  Annual Member
# 6647664        Dundas St E / Victoria St   3487.0  Casual Member
# 6647665            Toronto Inukshuk Park   4195.0  Annual Member
# 6647666                    12 Harbour St   1655.0  Annual Member
#
#            Start Time Fixed      End Time Fixed
# 0       2020-01-01 00:08:00 2020-01-01 00:19:00
# 1       2020-01-01 00:10:00 2020-01-01 00:17:00
# 2       2020-01-01 00:13:00 2020-01-01 00:22:00
# 3       2020-01-01 00:17:00 2020-01-01 00:38:00
# 4       2020-01-01 00:19:00 2020-01-01 00:34:00
# ...                     ...                 ...
# 6647662 2021-12-31 23:56:00 2022-01-01 00:02:00
# 6647663 2021-12-31 23:56:00 2022-01-01 00:09:00
# 6647664 2021-12-31 23:56:00 2022-01-01 00:02:00
# 6647665 2021-12-31 23:56:00 2022-01-01 00:08:00
# 6647666 2021-12-31 23:59:00 2022-01-01 00:21:00
#
# [6212591 rows x 11 columns]

# %%
df_trip_data.describe(include ='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#              Trip Id  Trip  Duration Start Station Id        Start Time  \
# count   6.176704e+06    6.176704e+06          6176704           6176704
# unique           NaN             NaN              622            858375
# top              NaN             NaN             7076  05/15/2021 13:38
# freq             NaN             NaN            57181                94
# first            NaN             NaN              NaN               NaN
# last             NaN             NaN              NaN               NaN
# mean    1.114087e+07    1.016074e+03              NaN               NaN
# std     2.205193e+06    5.527425e+03              NaN               NaN
# min     7.334128e+06    1.210000e+02              NaN               NaN
# 25%     9.226889e+06    4.700000e+02              NaN               NaN
# 50%     1.113613e+07    7.780000e+02              NaN               NaN
# 75%     1.306464e+07    1.198000e+03              NaN               NaN
# max     1.496490e+07    4.450681e+06              NaN               NaN
#
#              Start Station Name End Station Id          End Time  \
# count                   6176704        6176704           6176704
# unique                      738            623            857381
# top     York St / Queens Quay W           7076  05/16/2021 16:13
# freq                      57181          64489                65
# first                       NaN            NaN               NaN
# last                        NaN            NaN               NaN
# mean                        NaN            NaN               NaN
# std                         NaN            NaN               NaN
# min                         NaN            NaN               NaN
# 25%                         NaN            NaN               NaN
# 50%                         NaN            NaN               NaN
# 75%                         NaN            NaN               NaN
# max                         NaN            NaN               NaN
#
#                End Station Name    Bike Id      User Type  \
# count                   6176704  6176704.0        6176704
# unique                      741    12799.0              2
# top     York St / Queens Quay W     5880.0  Annual Member
# freq                      64489     1536.0        3932241
# first                       NaN        NaN            NaN
# last                        NaN        NaN            NaN
# mean                        NaN        NaN            NaN
# std                         NaN        NaN            NaN
# min                         NaN        NaN            NaN
# 25%                         NaN        NaN            NaN
# 50%                         NaN        NaN            NaN
# 75%                         NaN        NaN            NaN
# max                         NaN        NaN            NaN
#
#            Start Time Fixed       End Time Fixed
# count               6176704              6176704
# unique               858375               857381
# top     2021-05-15 13:38:00  2021-05-16 16:13:00
# freq                     94                   65
# first   2020-01-01 00:08:00  2020-01-01 00:17:00
# last    2022-02-28 23:59:00  2022-03-01 00:26:00
# mean                    NaN                  NaN
# std                     NaN                  NaN
# min                     NaN                  NaN
# 25%                     NaN                  NaN
# 50%                     NaN                  NaN
# 75%                     NaN                  NaN
# max                     NaN                  NaN

# %% [markdown]
# ### Compute Net Demand per Station

# %%
df_trip_data_start = df_trip_data.copy()
df_trip_data_start['Net Demand'] = 1

df_trip_data_end = df_trip_data.copy()
df_trip_data_end['Start Time Fixed'] = df_trip_data_end['End Time Fixed']
df_trip_data_end['Start Station Id'] = df_trip_data_end['End Station Id']
df_trip_data_end['Net Demand'] = -1

# %%
df_trip_data_net_demand = pd.concat([df_trip_data_start, df_trip_data_end], axis = 0)

# %%
df_trip_data_net_demand
# Out:
#          Trip  Duration Start Station Id        Start Time  \
# 0                 648.0             7003  01/01/2020 00:08
# 1                 419.0             7007  01/01/2020 00:10
# 2                 566.0             7113  01/01/2020 00:13
# 3                1274.0             7333  01/01/2020 00:17
# 4                 906.0             7009  01/01/2020 00:19
# ...                 ...              ...               ...
# 6647662           355.0             7472  12/31/2021 23:56
# 6647663           770.0             7076  12/31/2021 23:56
# 6647664           372.0             7472  12/31/2021 23:56
# 6647665           762.0             7569  12/31/2021 23:56
# 6647666          1307.0             7383  12/31/2021 23:59
#
#                       Start Station Name End Station Id          End Time  \
# 0               Madison Ave / Bloor St W           7271  01/01/2020 00:19
# 1                  College St / Huron St           7163  01/01/2020 00:17
# 2           Parliament St / Aberdeen Ave           7108  01/01/2020 00:22
# 3                King St E / Victoria St           7311  01/01/2020 00:38
# 4                  King St E / Jarvis St           7004  01/01/2020 00:34
# ...                                  ...            ...               ...
# 6647662      Dundas St E / Parliament St           7472  01/01/2022 00:02
# 6647663    Granby St / Church St - SMART           7076  01/01/2022 00:09
# 6647664      Dundas St E / Parliament St           7472  01/01/2022 00:02
# 6647665         King / Cowan Ave - SMART           7569  01/01/2022 00:08
# 6647666  Simcoe St / Wellington St South           7383  01/01/2022 00:21
#
#                         End Station Name  Bike Id      User Type  \
# 0        Yonge St / Alexander St - SMART   3104.0  Annual Member
# 1                     Yonge St / Wood St   2126.0  Annual Member
# 2                 Front St E / Cherry St   4425.0  Annual Member
# 3            Sherbourne St / Isabella St   4233.0  Annual Member
# 4                University Ave / Elm St   2341.0  Casual Member
# ...                                  ...      ...            ...
# 6647662        Dundas St E / Victoria St   4574.0  Casual Member
# 6647663          York St / Queens Quay W   5879.0  Annual Member
# 6647664        Dundas St E / Victoria St   3487.0  Casual Member
# 6647665            Toronto Inukshuk Park   4195.0  Annual Member
# 6647666                    12 Harbour St   1655.0  Annual Member
#
#            Start Time Fixed      End Time Fixed  Net Demand
# 0       2020-01-01 00:08:00 2020-01-01 00:19:00           1
# 1       2020-01-01 00:10:00 2020-01-01 00:17:00           1
# 2       2020-01-01 00:13:00 2020-01-01 00:22:00           1
# 3       2020-01-01 00:17:00 2020-01-01 00:38:00           1
# 4       2020-01-01 00:19:00 2020-01-01 00:34:00           1
# ...                     ...                 ...         ...
# 6647662 2022-01-01 00:02:00 2022-01-01 00:02:00          -1
# 6647663 2022-01-01 00:09:00 2022-01-01 00:09:00          -1
# 6647664 2022-01-01 00:02:00 2022-01-01 00:02:00          -1
# 6647665 2022-01-01 00:08:00 2022-01-01 00:08:00          -1
# 6647666 2022-01-01 00:21:00 2022-01-01 00:21:00          -1
#
# [12425182 rows x 12 columns]

# %%
df_trip_data_net_demand.columns
# Out:
# Index(['Start Station Id', 'Start Time', 'Start Station Name',
#        'End Station Id', 'End Time', 'End Station Name', 'Bike Id',
#        'User Type', 'Start Time Fixed', 'End Time Fixed', 'Net Demand'],
#       dtype='object')

# %%
df_trip_data_net_demand = df_trip_data_net_demand.rename(columns={"Start Time Fixed": "Time"})
df_trip_data_net_demand = df_trip_data_net_demand[['Start Station Id', 'Time','User Type', 'Net Demand']]
df_trip_data_net_demand
# Out:
#         Start Station Id                Time      User Type  Net Demand
# 0                   7003 2020-01-01 00:08:00  Annual Member           1
# 1                   7007 2020-01-01 00:10:00  Annual Member           1
# 2                   7113 2020-01-01 00:13:00  Annual Member           1
# 3                   7333 2020-01-01 00:17:00  Annual Member           1
# 4                   7009 2020-01-01 00:19:00  Casual Member           1
# ...                  ...                 ...            ...         ...
# 6647662             7472 2022-01-01 00:02:00  Casual Member          -1
# 6647663             7076 2022-01-01 00:09:00  Annual Member          -1
# 6647664             7472 2022-01-01 00:02:00  Casual Member          -1
# 6647665             7569 2022-01-01 00:08:00  Annual Member          -1
# 6647666             7383 2022-01-01 00:21:00  Annual Member          -1
#
# [12425182 rows x 4 columns]

# %% [markdown]
# ### Save Net Demand Per Station Dataset

# %%
data_path = "../data/02_trip_data_2020-01_2022-02_new.csv"
df_trip_data_net_demand.to_csv(data_path, index=False)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Load Trip Dataset

# %%
data_path = "../data/02_trip_data_2020-01_2022-02_new.csv"
df_trip_data = pd.read_csv(data_path, index_col=[0], parse_dates=['Time'])
df_trip_data.rename({'Time':'Start Time'}, inplace = True, axis = 1)

# %%
df_trip_data.head()
# Out:
#                           Start Time      User Type  Net Demand
# Start Station Id
# 7003             2020-01-01 00:08:00  Annual Member           1
# 7007             2020-01-01 00:10:00  Annual Member           1
# 7113             2020-01-01 00:13:00  Annual Member           1
# 7333             2020-01-01 00:17:00  Annual Member           1
# 7009             2020-01-01 00:19:00  Casual Member           1

# %%
df_trip_data.tail()
# Out:
#                           Start Time      User Type  Net Demand
# Start Station Id
# 7472             2022-01-01 00:02:00  Casual Member          -1
# 7076             2022-01-01 00:09:00  Annual Member          -1
# 7472             2022-01-01 00:02:00  Casual Member          -1
# 7569             2022-01-01 00:08:00  Annual Member          -1
# 7383             2022-01-01 00:21:00  Annual Member          -1

# %%
df_trip_data.reset_index(inplace = True)

# %%
df_trip_data.count()
# Out:
# Start Station Id    12425182
# Start Time          12425182
# User Type           12425182
# Net Demand          12425182
# dtype: int64

# %% [markdown]
# ### Bin Trips into Timeframes

# %%
df_trip_data['Start_Date'] = df_trip_data['Start Time'].apply(lambda x: hour_rounder(x))

# %%
df_trip_data['datehour'] = df_trip_data['Start_Date'].dt.hour

# %%
day_mapping = {0:'10PM-2AM',1:'2AM-6AM', 2:'6AM-10AM', 3:'10AM-2PM',4:'2PM-6PM', 5: '6PM-10PM', 6:'10PM-2AM'}
def hour_bin(i):
      return ((i%24)+2)//4

# %%
df_trip_data['Binned_Start_Time'] = df_trip_data['datehour'].apply(hour_bin).map(day_mapping)

# %%
df_trip_data.drop(columns = ['Start Time', 'datehour'], inplace = True)

# %%
df_trip_data
# Out:
#           Start Station Id      User Type  Net Demand Start_Date  \
# 0                     7003  Annual Member           1 2020-01-01
# 1                     7007  Annual Member           1 2020-01-01
# 2                     7113  Annual Member           1 2020-01-01
# 3                     7333  Annual Member           1 2020-01-01
# 4                     7009  Casual Member           1 2020-01-01
# ...                    ...            ...         ...        ...
# 12425177              7472  Casual Member          -1 2022-01-01
# 12425178              7076  Annual Member          -1 2022-01-01
# 12425179              7472  Casual Member          -1 2022-01-01
# 12425180              7569  Annual Member          -1 2022-01-01
# 12425181              7383  Annual Member          -1 2022-01-01
#
#          Binned_Start_Time
# 0                 10PM-2AM
# 1                 10PM-2AM
# 2                 10PM-2AM
# 3                 10PM-2AM
# 4                 10PM-2AM
# ...                    ...
# 12425177          10PM-2AM
# 12425178          10PM-2AM
# 12425179          10PM-2AM
# 12425180          10PM-2AM
# 12425181          10PM-2AM
#
# [12425182 rows x 5 columns]

# %%
df_trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12425182 entries, 0 to 12425181
# Data columns (total 5 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Start Station Id   int64
#  1   User Type          object
#  2   Net Demand         int64
#  3   Start_Date         datetime64[ns]
#  4   Binned_Start_Time  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 474.0+ MB

# %%
df_trip_data['Start_Date'] = df_trip_data['Start_Date'].dt.date

# %%
df_trip_data.head()
# Out:
#    Start Station Id      User Type  Net Demand  Start_Date Binned_Start_Time
# 0              7003  Annual Member           1  2020-01-01          10PM-2AM
# 1              7007  Annual Member           1  2020-01-01          10PM-2AM
# 2              7113  Annual Member           1  2020-01-01          10PM-2AM
# 3              7333  Annual Member           1  2020-01-01          10PM-2AM
# 4              7009  Casual Member           1  2020-01-01          10PM-2AM

# %%
df_trip_data['Start Station Id'] = df_trip_data['Start Station Id'].astype(str)

# %%
df_trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12425182 entries, 0 to 12425181
# Data columns (total 5 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Start Station Id   object
#  1   User Type          object
#  2   Net Demand         int64
#  3   Start_Date         object
#  4   Binned_Start_Time  object
# dtypes: int64(1), object(4)
# memory usage: 474.0+ MB

# %% [markdown]
# ### Importing Station Info

# %%
url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information.json'
resp = requests.get(url)
station_info = json.loads(resp.text)

# %%
df_station_info = pd.json_normalize(station_info, record_path=['data','stations'])

# %%
df_station_info['station_id'] = df_station_info['station_id'].astype(str)

# %%
df_station_info.head()
# Out:
#   station_id                          name physical_configuration        lat  \
# 0       7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 1       7001     Wellesley Station Green P                REGULAR  43.664964
# 2       7002    St. George St / Bloor St W                REGULAR  43.667333
# 3       7003      Madison Ave / Bloor St W                REGULAR  43.667158
# 4       7004       University Ave / Elm St                REGULAR  43.656518
#
#          lon  altitude                       address  capacity  \
# 0 -79.395954       0.0  Fort York  Blvd / Capreol Ct        35
# 1 -79.383550       0.0             Yonge / Wellesley        17
# 2 -79.399429       0.0    St. George St / Bloor St W        19
# 3 -79.402761       NaN      Madison Ave / Bloor St W        15
# 4 -79.389099       NaN       University Ave / Elm St        11
#
#                           rental_methods        groups          obcn  \
# 0  [KEY, TRANSITCARD, CREDITCARD, PHONE]            []  647-643-9607
# 1  [KEY, TRANSITCARD, CREDITCARD, PHONE]            []  416-617-9576
# 2  [KEY, TRANSITCARD, CREDITCARD, PHONE]            []  647-643-9615
# 3  [KEY, TRANSITCARD, CREDITCARD, PHONE]            []  647-631-4587
# 4  [KEY, TRANSITCARD, CREDITCARD, PHONE]  [P7004-7047]  647-643-9673
#
#    nearby_distance post_code cross_street
# 0            500.0       NaN          NaN
# 1            500.0   M4Y 1G7          NaN
# 2            500.0       NaN          NaN
# 3            500.0       NaN          NaN
# 4            500.0       NaN          NaN

# %%
df_station_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   station_id              618 non-null    object
#  1   name                    618 non-null    object
#  2   physical_configuration  618 non-null    object
#  3   lat                     618 non-null    float64
#  4   lon                     618 non-null    float64
#  5   altitude                608 non-null    float64
#  6   address                 618 non-null    object
#  7   capacity                618 non-null    int64
#  8   rental_methods          618 non-null    object
#  9   groups                  618 non-null    object
#  10  obcn                    618 non-null    object
#  11  nearby_distance         618 non-null    float64
#  12  post_code               303 non-null    object
#  13  cross_street            31 non-null     object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 67.7+ KB

# %%
all_stations = list(df_station_info['station_id'].unique())

# %%
all_stations
# Out:
# ['7000',
#  '7001',
#  '7002',
#  '7003',
#  '7004',
#  '7005',
#  '7006',
#  '7007',
#  '7008',
#  '7009',
#  '7010',
#  '7011',
#  '7012',
#  '7013',
#  '7014',
#  '7015',
#  '7016',
#  '7017',
#  '7018',
#  '7019',
#  '7020',
#  '7021',
#  '7022',
#  '7023',
#  '7024',
#  '7025',
#  '7026',
#  '7027',
#  '7028',
#  '7029',
#  '7030',
#  '7031',
#  '7032',
#  '7033',
#  '7034',
#  '7035',
#  '7036',
#  '7037',
#  '7038',
#  '7039',
#  '7040',
#  '7041',
#  '7042',
#  '7043',
#  '7044',
#  '7045',
#  '7046',
#  '7047',
#  '7048',
#  '7049',
#  '7050',
#  '7052',
#  '7053',
#  '7054',
#  '7055',
#  '7056',
#  '7057',
#  '7058',
#  '7059',
#  '7060',
#  '7061',
#  '7062',
#  '7063',
#  '7064',
#  '7065',
#  '7066',
#  '7067',
#  '7068',
#  '7069',
#  '7070',
#  '7071',
#  '7072',
#  '7073',
#  '7074',
#  '7075',
#  '7076',
#  '7077',
#  '7078',
#  '7079',
#  '7083',
#  '7084',
#  '7085',
#  '7086',
#  '7087',
#  '7088',
#  '7089',
#  '7090',
#  '7091',
#  '7092',
#  '7093',
#  '7094',
#  '7095',
#  '7096',
#  '7097',
#  '7098',
#  '7099',
#  '7100',
#  '7101',
#  '7102',
#  '7103',
#  '7104',
#  '7105',
#  '7106',
#  '7107',
#  '7108',
#  '7109',
#  '7110',
#  '7111',
#  '7112',
#  '7113',
#  '7114',
#  '7115',
#  '7117',
#  '7118',
#  '7119',
#  '7120',
#  '7121',
#  '7122',
#  '7123',
#  '7124',
#  '7126',
#  '7127',
#  '7128',
#  '7129',
#  '7130',
#  '7131',
#  '7132',
#  '7133',
#  '7134',
#  '7135',
#  '7136',
#  '7137',
#  '7138',
#  '7139',
#  '7140',
#  '7141',
#  '7142',
#  '7143',
#  '7144',
#  '7146',
#  '7147',
#  '7148',
#  '7149',
#  '7150',
#  '7151',
#  '7152',
#  '7153',
#  '7154',
#  '7155',
#  '7156',
#  '7157',
#  '7158',
#  '7160',
#  '7161',
#  '7162',
#  '7163',
#  '7164',
#  '7167',
#  '7168',
#  '7169',
#  '7170',
#  '7171',
#  '7172',
#  '7173',
#  '7174',
#  '7175',
#  '7176',
#  '7177',
#  '7178',
#  '7179',
#  '7180',
#  '7181',
#  '7182',
#  '7183',
#  '7184',
#  '7188',
#  '7189',
#  '7190',
#  '7191',
#  '7192',
#  '7193',
#  '7194',
#  '7195',
#  '7196',
#  '7197',
#  '7198',
#  '7199',
#  '7202',
#  '7203',
#  '7204',
#  '7205',
#  '7206',
#  '7207',
#  '7208',
#  '7209',
#  '7210',
#  '7211',
#  '7216',
#  '7217',
#  '7220',
#  '7221',
#  '7222',
#  '7223',
#  '7224',
#  '7225',
#  '7226',
#  '7227',
#  '7228',
#  '7229',
#  '7230',
#  '7231',
#  '7232',
#  '7233',
#  '7234',
#  '7235',
#  '7236',
#  '7237',
#  '7238',
#  '7239',
#  '7240',
#  '7241',
#  '7242',
#  '7243',
#  '7244',
#  '7245',
#  '7246',
#  '7247',
#  '7248',
#  '7249',
#  '7250',
#  '7251',
#  '7252',
#  '7253',
#  '7255',
#  '7256',
#  '7257',
#  '7258',
#  '7259',
#  '7260',
#  '7261',
#  '7262',
#  '7263',
#  '7264',
#  '7265',
#  '7266',
#  '7267',
#  '7268',
#  '7269',
#  '7270',
#  '7271',
#  '7272',
#  '7273',
#  '7274',
#  '7275',
#  '7276',
#  '7277',
#  '7278',
#  '7279',
#  '7280',
#  '7281',
#  '7282',
#  '7283',
#  '7284',
#  '7285',
#  '7286',
#  '7287',
#  '7288',
#  '7289',
#  '7291',
#  '7292',
#  '7293',
#  '7296',
#  '7297',
#  '7298',
#  '7299',
#  '7301',
#  '7302',
#  '7303',
#  '7309',
#  '7311',
#  '7312',
#  '7313',
#  '7314',
#  '7315',
#  '7316',
#  '7317',
#  '7318',
#  '7319',
#  '7320',
#  '7321',
#  '7322',
#  '7323',
#  '7324',
#  '7326',
#  '7327',
#  '7328',
#  '7329',
#  '7330',
#  '7331',
#  '7332',
#  '7333',
#  '7334',
#  '7335',
#  '7336',
#  '7337',
#  '7338',
#  '7339',
#  '7340',
#  '7341',
#  '7342',
#  '7343',
#  '7344',
#  '7345',
#  '7346',
#  '7347',
#  '7348',
#  '7349',
#  '7350',
#  '7351',
#  '7352',
#  '7353',
#  '7354',
#  '7355',
#  '7356',
#  '7357',
#  '7359',
#  '7360',
#  '7361',
#  '7362',
#  '7363',
#  '7364',
#  '7365',
#  '7366',
#  '7367',
#  '7368',
#  '7369',
#  '7371',
#  '7372',
#  '7373',
#  '7374',
#  '7375',
#  '7376',
#  '7377',
#  '7378',
#  '7379',
#  '7380',
#  '7381',
#  '7382',
#  '7383',
#  '7384',
#  '7385',
#  '7386',
#  '7387',
#  '7388',
#  '7389',
#  '7391',
#  '7392',
#  '7395',
#  '7398',
#  '7399',
#  '7400',
#  '7403',
#  '7404',
#  '7406',
#  '7407',
#  '7408',
#  '7409',
#  '7410',
#  '7411',
#  '7412',
#  '7413',
#  '7414',
#  '7415',
#  '7416',
#  '7417',
#  '7418',
#  '7419',
#  '7420',
#  '7422',
#  '7423',
#  '7424',
#  '7425',
#  '7426',
#  '7427',
#  '7428',
#  '7429',
#  '7430',
#  '7431',
#  '7432',
#  '7433',
#  '7434',
#  '7435',
#  '7437',
#  '7438',
#  '7440',
#  '7441',
#  '7442',
#  '7443',
#  '7444',
#  '7445',
#  '7446',
#  '7447',
#  '7448',
#  '7449',
#  '7450',
#  '7451',
#  '7452',
#  '7453',
#  '7454',
#  '7455',
#  '7457',
#  '7458',
#  '7459',
#  '7460',
#  '7461',
#  '7462',
#  '7463',
#  '7465',
#  '7466',
#  '7467',
#  '7468',
#  '7469',
#  '7471',
#  '7472',
#  '7473',
#  '7474',
#  '7475',
#  '7476',
#  '7477',
#  '7478',
#  '7479',
#  '7480',
#  '7482',
#  '7483',
#  '7484',
#  '7485',
#  '7486',
#  '7487',
#  '7488',
#  '7489',
#  '7491',
#  '7492',
#  '7493',
#  '7494',
#  '7496',
#  '7497',
#  '7501',
#  '7502',
#  '7503',
#  '7504',
#  '7505',
#  '7506',
#  '7508',
#  '7509',
#  '7514',
#  '7515',
#  '7516',
#  '7517',
#  '7518',
#  '7519',
#  '7520',
#  '7521',
#  '7522',
#  '7523',
#  '7524',
#  '7525',
#  '7526',
#  '7527',
#  '7528',
#  '7529',
#  '7530',
#  '7531',
#  '7533',
#  '7534',
#  '7535',
#  '7536',
#  '7537',
#  '7538',
#  '7539',
#  '7540',
#  '7541',
#  '7542',
#  '7543',
#  '7544',
#  '7545',
#  '7546',
#  '7547',
#  '7548',
#  '7549',
#  '7551',
#  '7552',
#  '7553',
#  '7554',
#  '7555',
#  '7556',
#  '7557',
#  '7558',
#  '7559',
#  '7560',
#  '7561',
#  '7562',
#  '7563',
#  '7564',
#  '7565',
#  '7566',
#  '7567',
#  '7568',
#  '7569',
#  '7570',
#  '7571',
#  '7572',
#  '7575',
#  '7576',
#  '7577',
#  '7578',
#  '7579',
#  '7580',
#  '7581',
#  '7582',
#  '7583',
#  '7584',
#  '7585',
#  '7586',
#  '7587',
#  '7588',
#  '7589',
#  '7590',
#  '7591',
#  '7593',
#  '7594',
#  '7595',
#  '7596',
#  '7597',
#  '7598',
#  '7599',
#  '7600',
#  '7601',
#  '7602',
#  '7603',
#  '7604',
#  '7605',
#  '7606',
#  '7607',
#  '7608',
#  '7609',
#  '7610',
#  '7611',
#  '7612',
#  '7613',
#  '7614',
#  '7615',
#  '7616',
#  '7617',
#  '7618',
#  '7619',
#  '7620',
#  '7621',
#  '7622',
#  '7623',
#  '7624',
#  '7625',
#  '7626',
#  '7627',
#  '7629',
#  '7630',
#  '7631',
#  '7632',
#  '7633',
#  '7634',
#  '7635',
#  '7636',
#  '7637',
#  '7639',
#  '7640',
#  '7641',
#  '7642',
#  '7643',
#  '7644',
#  '7645',
#  '7646',
#  '7647',
#  '7648',
#  '7650',
#  '7653',
#  '7654',
#  '7655',
#  '7656',
#  '7657',
#  '7658',
#  '7659',
#  '7660',
#  '7662',
#  '7663',
#  '7664',
#  '7665',
#  '7666',
#  '7667',
#  '7668',
#  '7670',
#  '7671',
#  '7675',
#  '7676',
#  '7677',
#  '7678',
#  '7679',
#  '7680',
#  '7681',
#  '7682',
#  '7683',
#  '7684',
#  '7685',
#  '7686',
#  '7687',
#  '7688',
#  '7689',
#  '7691',
#  '7692',
#  '7693']

# %%
len(all_stations)
# Out:
# 618

# %%
trip_stations = list(df_trip_data['Start Station Id'].unique())

# %%
len(trip_stations)
# Out:
# 623

# %%
missing_stations = [i for i in trip_stations if i not in all_stations]

# %%
missing_stations
# Out:
# ['7470',
#  '7402',
#  '7116',
#  '7481',
#  '7051',
#  '7436',
#  '7358',
#  '7456',
#  '7254',
#  '7510',
#  '7573',
#  '7649',
#  '7651',
#  '7532',
#  '7394',
#  '7638']

# %%
# dropping stations that didn't have information in the station cross-reference. Opensource data has not been updated since 2021
df_trip_data_trim = df_trip_data[~df_trip_data['Start Station Id'].isin(missing_stations)]

# %%
df_trip_data_trim
# Out:
#          Start Station Id      User Type  Net Demand  Start_Date  \
# 0                    7003  Annual Member           1  2020-01-01
# 1                    7007  Annual Member           1  2020-01-01
# 2                    7113  Annual Member           1  2020-01-01
# 3                    7333  Annual Member           1  2020-01-01
# 4                    7009  Casual Member           1  2020-01-01
# ...                   ...            ...         ...         ...
# 12425177             7472  Casual Member          -1  2022-01-01
# 12425178             7076  Annual Member          -1  2022-01-01
# 12425179             7472  Casual Member          -1  2022-01-01
# 12425180             7569  Annual Member          -1  2022-01-01
# 12425181             7383  Annual Member          -1  2022-01-01
#
#          Binned_Start_Time
# 0                 10PM-2AM
# 1                 10PM-2AM
# 2                 10PM-2AM
# 3                 10PM-2AM
# 4                 10PM-2AM
# ...                    ...
# 12425177          10PM-2AM
# 12425178          10PM-2AM
# 12425179          10PM-2AM
# 12425180          10PM-2AM
# 12425181          10PM-2AM
#
# [12243065 rows x 5 columns]

# %% [markdown]
# ### Importing station status to confirm all stations that are in dataset are active

# %%
url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status'
resp = requests.get(url)
station_status = json.loads(resp.text)

# %%
df_station_status = pd.json_normalize(station_status, record_path=['data','stations'])

# %%
df_station_status
# Out:
#     station_id  num_bikes_available  num_bikes_disabled  num_docks_available  \
# 0         7000                    8                   1                   25
# 1         7001                    0                   1                   15
# 2         7002                    0                   1                   18
# 3         7003                    5                   0                   10
# 4         7004                    0                   1                   10
# ..         ...                  ...                 ...                  ...
# 618       7688                    3                   0                   12
# 619       7689                    6                   0                   20
# 620       7691                    3                   1                   14
# 621       7692                    9                   0                   17
# 622       7693                    7                   0                   12
#
#      num_docks_disabled  last_reported  is_charging_station      status  \
# 0                     1     1648599164                False  IN_SERVICE
# 1                     0     1648599230                False  IN_SERVICE
# 2                     0     1648599264                False  IN_SERVICE
# 3                     0     1648599240                False  IN_SERVICE
# 4                     0     1648599244                False  IN_SERVICE
# ..                  ...            ...                  ...         ...
# 618                   0     1648599226                False  IN_SERVICE
# 619                   0     1648599264                 True  IN_SERVICE
# 620                   1     1648599324                False  IN_SERVICE
# 621                   0     1648599405                 True  IN_SERVICE
# 622                   0     1648599298                False  IN_SERVICE
#
#      is_installed  is_renting  is_returning traffic  \
# 0               1           1             1    None
# 1               1           1             1    None
# 2               1           1             1    None
# 3               1           1             1    None
# 4               1           1             1    None
# ..            ...         ...           ...     ...
# 618             1           1             1    None
# 619             1           1             1    None
# 620             1           1             1    None
# 621             1           1             1    None
# 622             1           1             1    None
#
#      num_bikes_available_types.mechanical  num_bikes_available_types.ebike
# 0                                       8                                0
# 1                                       0                                0
# 2                                       0                                0
# 3                                       5                                0
# 4                                       0                                0
# ..                                    ...                              ...
# 618                                     3                                0
# 619                                     6                                0
# 620                                     3                                0
# 621                                     9                                0
# 622                                     7                                0
#
# [623 rows x 14 columns]

# %%
df_station_status['status'].unique()
# Out:
# array(['IN_SERVICE', 'END_OF_LIFE'], dtype=object)

# %%
disabled_stations = list(df_station_status[df_station_status['status']=='END_OF_LIFE']['station_id'])

# %%
disabled_missing_stations = [i for i in missing_stations if i  in disabled_stations]

# %%
disabled_missing_stations
# Out:
# []

# %% [markdown]
# ### Grouped Dataset - Net Demand per Station

# %%
df_trip_data_trim_binned = df_trip_data_trim.groupby(['Start Station Id','User Type','Start_Date','Binned_Start_Time'])[['Net Demand']].sum()

# %%
df_trip_data_trim_binned.reset_index(drop = False, inplace = True)
df_trip_data_trim_binned
# Out:
#         Start Station Id      User Type  Start_Date Binned_Start_Time  \
# 0                   7000  Annual Member  2020-01-01          10AM-2PM
# 1                   7000  Annual Member  2020-01-01          10PM-2AM
# 2                   7000  Annual Member  2020-01-01           2PM-6PM
# 3                   7000  Annual Member  2020-01-01          6PM-10PM
# 4                   7000  Annual Member  2020-01-02          10AM-2PM
# ...                  ...            ...         ...               ...
# 2348247             7681  Casual Member  2022-02-16          6PM-10PM
# 2348248             7681  Casual Member  2022-02-20           2PM-6PM
# 2348249             7681  Casual Member  2022-02-22           2PM-6PM
# 2348250             7681  Casual Member  2022-02-23          6AM-10AM
# 2348251             7681  Casual Member  2022-02-28          10AM-2PM
#
#          Net Demand
# 0                 0
# 1                 1
# 2                -2
# 3                -1
# 4                 4
# ...             ...
# 2348247          -2
# 2348248           0
# 2348249           0
# 2348250           0
# 2348251           2
#
# [2348252 rows x 5 columns]

# %%
df_trip_data_trim_binned.groupby(['Start Station Id']).count()
# Out:
#                   User Type  Start_Date  Binned_Start_Time  Net Demand
# Start Station Id
# 7000                   6859        6859               6859        6859
# 7001                   6054        6054               6054        6054
# 7002                   6179        6179               6179        6179
# 7003                   5496        5496               5496        5496
# 7004                   4899        4899               4899        4899
# ...                     ...         ...                ...         ...
# 7677                    802         802                802         802
# 7678                    202         202                202         202
# 7679                     90          90                 90          90
# 7680                    306         306                306         306
# 7681                    535         535                535         535
#
# [607 rows x 4 columns]

# %% [markdown]
# ### Merge Binned Trip Data with Station Info

# %%
temp_datetime_final = df_trip_data_trim_binned.merge(df_station_info, left_on = ['Start Station Id'], right_on = ['station_id'], how = 'inner')

# %%
temp_datetime_final.head()
# Out:
#   Start Station Id      User Type  Start_Date Binned_Start_Time  Net Demand  \
# 0             7000  Annual Member  2020-01-01          10AM-2PM           0
# 1             7000  Annual Member  2020-01-01          10PM-2AM           1
# 2             7000  Annual Member  2020-01-01           2PM-6PM          -2
# 3             7000  Annual Member  2020-01-01          6PM-10PM          -1
# 4             7000  Annual Member  2020-01-02          10AM-2PM           4
#
#   station_id                          name physical_configuration        lat  \
# 0       7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 1       7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 2       7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 3       7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 4       7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
#
#          lon  altitude                       address  capacity  \
# 0 -79.395954       0.0  Fort York  Blvd / Capreol Ct        35
# 1 -79.395954       0.0  Fort York  Blvd / Capreol Ct        35
# 2 -79.395954       0.0  Fort York  Blvd / Capreol Ct        35
# 3 -79.395954       0.0  Fort York  Blvd / Capreol Ct        35
# 4 -79.395954       0.0  Fort York  Blvd / Capreol Ct        35
#
#                           rental_methods groups          obcn  \
# 0  [KEY, TRANSITCARD, CREDITCARD, PHONE]     []  647-643-9607
# 1  [KEY, TRANSITCARD, CREDITCARD, PHONE]     []  647-643-9607
# 2  [KEY, TRANSITCARD, CREDITCARD, PHONE]     []  647-643-9607
# 3  [KEY, TRANSITCARD, CREDITCARD, PHONE]     []  647-643-9607
# 4  [KEY, TRANSITCARD, CREDITCARD, PHONE]     []  647-643-9607
#
#    nearby_distance post_code cross_street
# 0            500.0       NaN          NaN
# 1            500.0       NaN          NaN
# 2            500.0       NaN          NaN
# 3            500.0       NaN          NaN
# 4            500.0       NaN          NaN

# %% [markdown]
# #### Save Binned Net Demand with Station Info

# %%
temp_datetime_final.to_csv('/data/station_id_and_net_demand.csv')

# %%
temp_datetime_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2348252 entries, 0 to 2348251
# Data columns (total 19 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Start Station Id        object
#  1   User Type               object
#  2   Start_Date              object
#  3   Binned_Start_Time       object
#  4   Net Demand              int64
#  5   station_id              object
#  6   name                    object
#  7   physical_configuration  object
#  8   lat                     float64
#  9   lon                     float64
#  10  altitude                float64
#  11  address                 object
#  12  capacity                int64
#  13  rental_methods          object
#  14  groups                  object
#  15  obcn                    object
#  16  nearby_distance         float64
#  17  post_code               object
#  18  cross_street            object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 358.3+ MB

# %% [markdown]
# ### Load Binned Net Demand with Station Info

# %%
df_binned_net_demand_w_station = pd.read_csv('/data/station_id_and_net_demand.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (16,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_binned_net_demand_w_station = df_binned_net_demand_w_station.drop(['Unnamed: 0','rental_methods',
                                                                      'address','groups','obcn',
                                                                      'nearby_distance','post_code','cross_street'], axis = 1)

# %%
df_binned_net_demand_w_station.head(5)
# Out:
#    Start Station Id      User Type  Start_Date Binned_Start_Time  Net Demand  \
# 0              7000  Annual Member  2020-01-01          10AM-2PM           0
# 1              7000  Annual Member  2020-01-01          10PM-2AM           1
# 2              7000  Annual Member  2020-01-01           2PM-6PM          -2
# 3              7000  Annual Member  2020-01-01          6PM-10PM          -1
# 4              7000  Annual Member  2020-01-02          10AM-2PM           4
#
#    station_id                          name physical_configuration        lat  \
# 0        7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 1        7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 2        7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 3        7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
# 4        7000  Fort York  Blvd / Capreol Ct                REGULAR  43.639832
#
#          lon  altitude  capacity
# 0 -79.395954       0.0        35
# 1 -79.395954       0.0        35
# 2 -79.395954       0.0        35
# 3 -79.395954       0.0        35
# 4 -79.395954       0.0        35

# %% [markdown]
# ### Add Station Info with POIs

# %%
df_station_info_pois = pd.read_csv('../data/station_info_w_POI.csv').drop('Unnamed: 0',axis=1)
df_station_info_pois
# Out:
#      station_id nearest_transit  POI_distance
# 0          7000       St Andrew      1.249617
# 1          7001       Wellesley      0.065552
# 2          7002       St George      0.110642
# 3          7003         Spadina      0.128092
# 4          7004      St Patrick      0.197084
# ..          ...             ...           ...
# 612        7686            King      0.612584
# 613        7687        Dufferin      0.113285
# 614        7688           Keele      1.214575
# 615        7689            Pape      0.071014
# 616        7691        Christie      0.859951
#
# [617 rows x 3 columns]

# %%
df_with_pois = pd.merge(left = df_binned_net_demand_w_station.reset_index(),
                        right = df_station_info_pois,
                        left_on = 'Start Station Id',
                        right_on = 'station_id',
                        copy = False
                        )
df_with_pois.columns
# Out:
# Index(['index', 'Start Station Id', 'User Type', 'Start_Date',
#        'Binned_Start_Time', 'Net Demand', 'station_id_x', 'name',
#        'physical_configuration', 'lat', 'lon', 'altitude', 'capacity',
#        'station_id_y', 'nearest_transit', 'POI_distance'],
#       dtype='object')

# %%
df_binned_net_demand_w_station_pois = df_with_pois[['Start Station Id', 'User Type', 'Start_Date',
                                                   'Binned_Start_Time', 
                                                   'lat', 'lon', 'altitude', 'capacity',
                                                   'nearest_transit', 'POI_distance','Net Demand']]

# %%
df_binned_net_demand_w_station_pois
# Out:
#          Start Station Id      User Type  Start_Date Binned_Start_Time  \
# 0                    7000  Annual Member  2020-01-01          10AM-2PM
# 1                    7000  Annual Member  2020-01-01          10PM-2AM
# 2                    7000  Annual Member  2020-01-01           2PM-6PM
# 3                    7000  Annual Member  2020-01-01          6PM-10PM
# 4                    7000  Annual Member  2020-01-02          10AM-2PM
# ...                   ...            ...         ...               ...
# 2348247              7681  Casual Member  2022-02-16          6PM-10PM
# 2348248              7681  Casual Member  2022-02-20           2PM-6PM
# 2348249              7681  Casual Member  2022-02-22           2PM-6PM
# 2348250              7681  Casual Member  2022-02-23          6AM-10AM
# 2348251              7681  Casual Member  2022-02-28          10AM-2PM
#
#                lat        lon  altitude  capacity nearest_transit  \
# 0        43.639832 -79.395954       0.0        35       St Andrew
# 1        43.639832 -79.395954       0.0        35       St Andrew
# 2        43.639832 -79.395954       0.0        35       St Andrew
# 3        43.639832 -79.395954       0.0        35       St Andrew
# 4        43.639832 -79.395954       0.0        35       St Andrew
# ...            ...        ...       ...       ...             ...
# 2348247  43.654484 -79.341057       0.0        24         Chester
# 2348248  43.654484 -79.341057       0.0        24         Chester
# 2348249  43.654484 -79.341057       0.0        24         Chester
# 2348250  43.654484 -79.341057       0.0        24         Chester
# 2348251  43.654484 -79.341057       0.0        24         Chester
#
#          POI_distance  Net Demand
# 0            1.249617           0
# 1            1.249617           1
# 2            1.249617          -2
# 3            1.249617          -1
# 4            1.249617           4
# ...               ...         ...
# 2348247      2.795657          -2
# 2348248      2.795657           0
# 2348249      2.795657           0
# 2348250      2.795657           0
# 2348251      2.795657           2
#
# [2348252 rows x 11 columns]

# %% [markdown]
# ### Add Weather Data

# %%
## TODO: REFERENCE DATA FILE PROPERLY
df_weather_info = pd.read_csv('../data/weather_data.csv',parse_dates=['Date/Time (LST)'])
df_weather_info
# Out:
#           Date/Time (LST)  Temp (°C)  Precip. Amount (mm)  Wind Spd (km/h)  \
# 0     2020-01-01 00:00:00        0.2                  0.0             35.0
# 1     2020-01-01 00:30:00        0.2                  0.0             35.0
# 2     2020-01-01 01:00:00        0.1                  0.0             34.0
# 3     2020-01-01 01:30:00        0.1                  0.0             34.0
# 4     2020-01-01 02:00:00        0.0                  0.0             34.0
# ...                   ...        ...                  ...              ...
# 37914 2022-02-28 21:00:00       -3.8                  0.0             28.0
# 37915 2022-02-28 21:30:00       -3.8                  0.0             28.0
# 37916 2022-02-28 22:00:00       -3.4                  0.0             18.0
# 37917 2022-02-28 22:30:00       -3.4                  0.0             18.0
# 37918 2022-02-28 23:00:00       -3.2                  0.0             26.0
#
#        Wind Dir (10s deg)  Visibility (km) Weather
# 0                    25.0             16.1   Other
# 1                    25.0             16.1   Other
# 2                    25.0             16.1   Other
# 3                    25.0             16.1   Other
# 4                    25.0             16.1   Other
# ...                   ...              ...     ...
# 37914                 7.0             16.1   Other
# 37915                 7.0             16.1   Other
# 37916                 8.0             16.1   Other
# 37917                 8.0             16.1   Other
# 37918                 8.0             16.1   Other
#
# [37919 rows x 7 columns]

# %%
df_weather_info['Start_Date'] = df_weather_info['Date/Time (LST)'].apply(lambda x: hour_rounder(x))

# %%
df_weather_info['datehour'] = df_weather_info['Start_Date'].dt.hour

# %%
df_weather_info['Binned_Start_Time'] = df_weather_info['datehour'].apply(hour_bin).map(day_mapping)

# %%
df_weather_info.drop(columns = ['Date/Time (LST)', 'datehour'], inplace = True)

# %%
df_weather_info['Start_Date'] = df_weather_info['Start_Date'].dt.date

# %%
df_weather_info_binned = df_weather_info.groupby(['Start_Date', 'Binned_Start_Time']).mean().reset_index()
df_weather_info_binned['Start_Date'] = df_weather_info_binned['Start_Date'].astype("string")
df_weather_info_binned['Binned_Start_Time'] = df_weather_info_binned['Binned_Start_Time'].astype("string")

# %%
df_weather_info_binned.dtypes
# Out:
# Start_Date              string
# Binned_Start_Time       string
# Temp (°C)              float64
# Precip. Amount (mm)    float64
# Wind Spd (km/h)        float64
# Wind Dir (10s deg)     float64
# Visibility (km)        float64
# dtype: object

# %%
df_binned_net_demand_w_station_pois.head(10)
# Out:
#    Start Station Id      User Type  Start_Date Binned_Start_Time        lat  \
# 0              7000  Annual Member  2020-01-01          10AM-2PM  43.639832
# 1              7000  Annual Member  2020-01-01          10PM-2AM  43.639832
# 2              7000  Annual Member  2020-01-01           2PM-6PM  43.639832
# 3              7000  Annual Member  2020-01-01          6PM-10PM  43.639832
# 4              7000  Annual Member  2020-01-02          10AM-2PM  43.639832
# 5              7000  Annual Member  2020-01-02           2PM-6PM  43.639832
# 6              7000  Annual Member  2020-01-02          6AM-10AM  43.639832
# 7              7000  Annual Member  2020-01-02          6PM-10PM  43.639832
# 8              7000  Annual Member  2020-01-03          10AM-2PM  43.639832
# 9              7000  Annual Member  2020-01-03          10PM-2AM  43.639832
#
#          lon  altitude  capacity nearest_transit  POI_distance  Net Demand
# 0 -79.395954       0.0        35       St Andrew      1.249617           0
# 1 -79.395954       0.0        35       St Andrew      1.249617           1
# 2 -79.395954       0.0        35       St Andrew      1.249617          -2
# 3 -79.395954       0.0        35       St Andrew      1.249617          -1
# 4 -79.395954       0.0        35       St Andrew      1.249617           4
# 5 -79.395954       0.0        35       St Andrew      1.249617          -1
# 6 -79.395954       0.0        35       St Andrew      1.249617           9
# 7 -79.395954       0.0        35       St Andrew      1.249617          -2
# 8 -79.395954       0.0        35       St Andrew      1.249617           2
# 9 -79.395954       0.0        35       St Andrew      1.249617           0

# %% [markdown]
# #### Merge Weather data with rest of the dataset

# %%
df_full_net_demand = pd.merge(left = df_binned_net_demand_w_station_pois,
                        right = df_weather_info_binned,
                        left_on = ['Start_Date', 'Binned_Start_Time'],
                        right_on = ['Start_Date', 'Binned_Start_Time'],
                        how = 'inner'
                        )

# %%
df_full_net_demand
# Out:
#          Start Station Id      User Type  Start_Date Binned_Start_Time  \
# 0                    7000  Annual Member  2020-01-01          10AM-2PM
# 1                    7000  Casual Member  2020-01-01          10AM-2PM
# 2                    7001  Annual Member  2020-01-01          10AM-2PM
# 3                    7003  Annual Member  2020-01-01          10AM-2PM
# 4                    7005  Annual Member  2020-01-01          10AM-2PM
# ...                   ...            ...         ...               ...
# 2348240              7378  Annual Member  2020-03-29           2AM-6AM
# 2348241              7409  Annual Member  2020-03-29           2AM-6AM
# 2348242              7409  Casual Member  2020-03-29           2AM-6AM
# 2348243              7412  Annual Member  2020-03-29           2AM-6AM
# 2348244              7411  Annual Member  2021-01-01          6AM-10AM
#
#                lat        lon  altitude  capacity nearest_transit  \
# 0        43.639832 -79.395954       0.0        35       St Andrew
# 1        43.639832 -79.395954       0.0        35       St Andrew
# 2        43.664964 -79.383550       0.0        17       Wellesley
# 3        43.667158 -79.402761       NaN        15         Spadina
# 4        43.648001 -79.383177       0.0        19       St Andrew
# ...            ...        ...       ...       ...             ...
# 2348240  43.697597 -79.396540       0.0        15      Davisville
# 2348241  43.668340 -79.382350       0.0        19       Wellesley
# 2348242  43.668340 -79.382350       0.0        19       Wellesley
# 2348243  43.641785 -79.413115       0.0        23   Exhibition GO
# 2348244  43.635023 -79.399505       0.0        22       St Andrew
#
#          POI_distance  Net Demand  Temp (°C)  Precip. Amount (mm)  \
# 0            1.249617           0      0.250                0.000
# 1            1.249617           2      0.250                0.000
# 2            0.065552           0      0.250                0.000
# 3            0.128092           1      0.250                0.000
# 4            0.136665          -1      0.250                0.000
# ...               ...         ...        ...                  ...
# 2348240      0.043908           1      4.875                0.425
# 2348241      0.334893          -1      4.875                0.425
# 2348242      0.334893          -1      4.875                0.425
# 2348243      0.798333          -1      4.875                0.425
# 2348244      1.836402          -1      0.775                0.000
#
#          Wind Spd (km/h)  Wind Dir (10s deg)  Visibility (km)
# 0                  34.50                25.0           16.100
# 1                  34.50                25.0           16.100
# 2                  34.50                25.0           16.100
# 3                  34.50                25.0           16.100
# 4                  34.50                25.0           16.100
# ...                  ...                 ...              ...
# 2348240            43.25                 6.0           10.075
# 2348241            43.25                 6.0           10.075
# 2348242            43.25                 6.0           10.075
# 2348243            43.25                 6.0           10.075
# 2348244             6.00                21.0           16.100
#
# [2348245 rows x 16 columns]

# %%
df_full_net_demand.columns
# Out:
# Index(['Start Station Id', 'User Type', 'Start_Date', 'Binned_Start_Time',
#        'lat', 'lon', 'altitude', 'capacity', 'nearest_transit', 'POI_distance',
#        'Net Demand', 'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)',
#        'Wind Dir (10s deg)', 'Visibility (km)'],
#       dtype='object')

# %%
df_full_net_demand = df_full_net_demand[['Start Station Id', 'Start_Date', 'Binned_Start_Time',
       'lat', 'lon', 'capacity', 'nearest_transit', 'POI_distance',
       'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)',
       'Wind Dir (10s deg)', 'Visibility (km)','Net Demand']]

# %% [markdown]
# ### Add Day & Holiday **Features**

# %%
df_full_net_demand
# Out:
#          Start Station Id Start_Date Binned_Start_Time        lat        lon  \
# 0                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 1                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 2                    7001 2020-01-01          10AM-2PM  43.664964 -79.383550
# 3                    7003 2020-01-01          10AM-2PM  43.667158 -79.402761
# 4                    7005 2020-01-01          10AM-2PM  43.648001 -79.383177
# ...                   ...        ...               ...        ...        ...
# 2348240              7378 2020-03-29           2AM-6AM  43.697597 -79.396540
# 2348241              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348242              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348243              7412 2020-03-29           2AM-6AM  43.641785 -79.413115
# 2348244              7411 2021-01-01          6AM-10AM  43.635023 -79.399505
#
#          capacity nearest_transit  POI_distance  Temp (°C)  \
# 0              35       St Andrew      1.249617      0.250
# 1              35       St Andrew      1.249617      0.250
# 2              17       Wellesley      0.065552      0.250
# 3              15         Spadina      0.128092      0.250
# 4              19       St Andrew      0.136665      0.250
# ...           ...             ...           ...        ...
# 2348240        15      Davisville      0.043908      4.875
# 2348241        19       Wellesley      0.334893      4.875
# 2348242        19       Wellesley      0.334893      4.875
# 2348243        23   Exhibition GO      0.798333      4.875
# 2348244        22       St Andrew      1.836402      0.775
#
#          Precip. Amount (mm)  Wind Spd (km/h)  Wind Dir (10s deg)  \
# 0                      0.000            34.50                25.0
# 1                      0.000            34.50                25.0
# 2                      0.000            34.50                25.0
# 3                      0.000            34.50                25.0
# 4                      0.000            34.50                25.0
# ...                      ...              ...                 ...
# 2348240                0.425            43.25                 6.0
# 2348241                0.425            43.25                 6.0
# 2348242                0.425            43.25                 6.0
# 2348243                0.425            43.25                 6.0
# 2348244                0.000             6.00                21.0
#
#          Visibility (km)  Net Demand
# 0                 16.100           0
# 1                 16.100           2
# 2                 16.100           0
# 3                 16.100           1
# 4                 16.100          -1
# ...                  ...         ...
# 2348240           10.075           1
# 2348241           10.075          -1
# 2348242           10.075          -1
# 2348243           10.075          -1
# 2348244           16.100          -1
#
# [2348245 rows x 14 columns]

# %%
canada_holidays = holidays.Canada (years = [2020, 2021, 2022])

# %%
canada_holidays
# Out:
# {datetime.date(2020, 1, 1): "New Year's Day",
#  datetime.date(2020, 2, 17): 'Family Day',
#  datetime.date(2020, 4, 10): 'Good Friday',
#  datetime.date(2020, 5, 18): 'Victoria Day',
#  datetime.date(2020, 7, 1): 'Canada Day',
#  datetime.date(2020, 8, 3): 'Civic Holiday',
#  datetime.date(2020, 9, 7): 'Labour Day',
#  datetime.date(2020, 10, 12): 'Thanksgiving',
#  datetime.date(2020, 12, 25): 'Christmas Day',
#  datetime.date(2020, 12, 28): 'Boxing Day (Observed)',
#  datetime.date(2021, 1, 1): "New Year's Day",
#  datetime.date(2021, 2, 15): 'Family Day',
#  datetime.date(2021, 4, 2): 'Good Friday',
#  datetime.date(2021, 5, 24): 'Victoria Day',
#  datetime.date(2021, 7, 1): 'Canada Day',
#  datetime.date(2021, 8, 2): 'Civic Holiday',
#  datetime.date(2021, 9, 6): 'Labour Day',
#  datetime.date(2021, 10, 11): 'Thanksgiving',
#  datetime.date(2021, 12, 24): 'Christmas Day (Observed)',
#  datetime.date(2021, 12, 25): 'Christmas Day',
#  datetime.date(2021, 12, 27): 'Boxing Day (Observed)',
#  datetime.date(2021, 12, 31): "New Year's Day (Observed)",
#  datetime.date(2022, 1, 1): "New Year's Day",
#  datetime.date(2022, 2, 21): 'Family Day',
#  datetime.date(2022, 4, 15): 'Good Friday',
#  datetime.date(2022, 5, 23): 'Victoria Day',
#  datetime.date(2022, 7, 1): 'Canada Day',
#  datetime.date(2022, 8, 1): 'Civic Holiday',
#  datetime.date(2022, 9, 5): 'Labour Day',
#  datetime.date(2022, 10, 10): 'Thanksgiving',
#  datetime.date(2022, 12, 25): 'Christmas Day',
#  datetime.date(2022, 12, 26): 'Christmas Day (Observed)',
#  datetime.date(2022, 12, 27): 'Boxing Day (Observed)'}

# %%
df_full_net_demand['Holiday'] = df_full_net_demand['Start_Date'].isin(canada_holidays).astype(int)
df_full_net_demand
# Out:
#          Start Station Id Start_Date Binned_Start_Time        lat        lon  \
# 0                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 1                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 2                    7001 2020-01-01          10AM-2PM  43.664964 -79.383550
# 3                    7003 2020-01-01          10AM-2PM  43.667158 -79.402761
# 4                    7005 2020-01-01          10AM-2PM  43.648001 -79.383177
# ...                   ...        ...               ...        ...        ...
# 2348240              7378 2020-03-29           2AM-6AM  43.697597 -79.396540
# 2348241              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348242              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348243              7412 2020-03-29           2AM-6AM  43.641785 -79.413115
# 2348244              7411 2021-01-01          6AM-10AM  43.635023 -79.399505
#
#          capacity nearest_transit  POI_distance  Temp (°C)  \
# 0              35       St Andrew      1.249617      0.250
# 1              35       St Andrew      1.249617      0.250
# 2              17       Wellesley      0.065552      0.250
# 3              15         Spadina      0.128092      0.250
# 4              19       St Andrew      0.136665      0.250
# ...           ...             ...           ...        ...
# 2348240        15      Davisville      0.043908      4.875
# 2348241        19       Wellesley      0.334893      4.875
# 2348242        19       Wellesley      0.334893      4.875
# 2348243        23   Exhibition GO      0.798333      4.875
# 2348244        22       St Andrew      1.836402      0.775
#
#          Precip. Amount (mm)  Wind Spd (km/h)  Wind Dir (10s deg)  \
# 0                      0.000            34.50                25.0
# 1                      0.000            34.50                25.0
# 2                      0.000            34.50                25.0
# 3                      0.000            34.50                25.0
# 4                      0.000            34.50                25.0
# ...                      ...              ...                 ...
# 2348240                0.425            43.25                 6.0
# 2348241                0.425            43.25                 6.0
# 2348242                0.425            43.25                 6.0
# 2348243                0.425            43.25                 6.0
# 2348244                0.000             6.00                21.0
#
#          Visibility (km)  Net Demand  Holiday
# 0                 16.100           0        1
# 1                 16.100           2        1
# 2                 16.100           0        1
# 3                 16.100           1        1
# 4                 16.100          -1        1
# ...                  ...         ...      ...
# 2348240           10.075           1        0
# 2348241           10.075          -1        0
# 2348242           10.075          -1        0
# 2348243           10.075          -1        0
# 2348244           16.100          -1        1
#
# [2348245 rows x 15 columns]

# %%
df_full_net_demand["Day_Of_Week"] = df_full_net_demand["Start_Date"].dt.weekday

# %%
df_full_net_demand["Is_Weekend"] = (df_full_net_demand["Day_Of_Week"] >= 5).astype(int)

# %%
df_full_net_demand
# Out:
#          Start Station Id Start_Date Binned_Start_Time        lat        lon  \
# 0                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 1                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 2                    7001 2020-01-01          10AM-2PM  43.664964 -79.383550
# 3                    7003 2020-01-01          10AM-2PM  43.667158 -79.402761
# 4                    7005 2020-01-01          10AM-2PM  43.648001 -79.383177
# ...                   ...        ...               ...        ...        ...
# 2348240              7378 2020-03-29           2AM-6AM  43.697597 -79.396540
# 2348241              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348242              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348243              7412 2020-03-29           2AM-6AM  43.641785 -79.413115
# 2348244              7411 2021-01-01          6AM-10AM  43.635023 -79.399505
#
#          capacity nearest_transit  POI_distance  Temp (°C)  \
# 0              35       St Andrew      1.249617      0.250
# 1              35       St Andrew      1.249617      0.250
# 2              17       Wellesley      0.065552      0.250
# 3              15         Spadina      0.128092      0.250
# 4              19       St Andrew      0.136665      0.250
# ...           ...             ...           ...        ...
# 2348240        15      Davisville      0.043908      4.875
# 2348241        19       Wellesley      0.334893      4.875
# 2348242        19       Wellesley      0.334893      4.875
# 2348243        23   Exhibition GO      0.798333      4.875
# 2348244        22       St Andrew      1.836402      0.775
#
#          Precip. Amount (mm)  Wind Spd (km/h)  Wind Dir (10s deg)  \
# 0                      0.000            34.50                25.0
# 1                      0.000            34.50                25.0
# 2                      0.000            34.50                25.0
# 3                      0.000            34.50                25.0
# 4                      0.000            34.50                25.0
# ...                      ...              ...                 ...
# 2348240                0.425            43.25                 6.0
# 2348241                0.425            43.25                 6.0
# 2348242                0.425            43.25                 6.0
# 2348243                0.425            43.25                 6.0
# 2348244                0.000             6.00                21.0
#
#          Visibility (km)  Net Demand  Holiday  Day_Of_Week  Is_Weekend
# 0                 16.100           0        1            2           0
# 1                 16.100           2        1            2           0
# 2                 16.100           0        1            2           0
# 3                 16.100           1        1            2           0
# 4                 16.100          -1        1            2           0
# ...                  ...         ...      ...          ...         ...
# 2348240           10.075           1        0            6           1
# 2348241           10.075          -1        0            6           1
# 2348242           10.075          -1        0            6           1
# 2348243           10.075          -1        0            6           1
# 2348244           16.100          -1        1            4           0
#
# [2348245 rows x 17 columns]

# %%
df_full_net_demand['Year']= pd.DatetimeIndex(df_full_net_demand['Start_Date']).year

# %%
df_full_net_demand['Month']= pd.DatetimeIndex(df_full_net_demand['Start_Date']).month

# %%
df_full_net_demand['Day of Month']= df_full_net_demand['Start_Date'].dt.strftime('%d')
df_full_net_demand
# Out:
#          Start Station Id Start_Date Binned_Start_Time        lat        lon  \
# 0                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 1                    7000 2020-01-01          10AM-2PM  43.639832 -79.395954
# 2                    7001 2020-01-01          10AM-2PM  43.664964 -79.383550
# 3                    7003 2020-01-01          10AM-2PM  43.667158 -79.402761
# 4                    7005 2020-01-01          10AM-2PM  43.648001 -79.383177
# ...                   ...        ...               ...        ...        ...
# 2348240              7378 2020-03-29           2AM-6AM  43.697597 -79.396540
# 2348241              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348242              7409 2020-03-29           2AM-6AM  43.668340 -79.382350
# 2348243              7412 2020-03-29           2AM-6AM  43.641785 -79.413115
# 2348244              7411 2021-01-01          6AM-10AM  43.635023 -79.399505
#
#          capacity nearest_transit  POI_distance  Temp (°C)  \
# 0              35       St Andrew      1.249617      0.250
# 1              35       St Andrew      1.249617      0.250
# 2              17       Wellesley      0.065552      0.250
# 3              15         Spadina      0.128092      0.250
# 4              19       St Andrew      0.136665      0.250
# ...           ...             ...           ...        ...
# 2348240        15      Davisville      0.043908      4.875
# 2348241        19       Wellesley      0.334893      4.875
# 2348242        19       Wellesley      0.334893      4.875
# 2348243        23   Exhibition GO      0.798333      4.875
# 2348244        22       St Andrew      1.836402      0.775
#
#          Precip. Amount (mm)  Wind Spd (km/h)  Wind Dir (10s deg)  \
# 0                      0.000            34.50                25.0
# 1                      0.000            34.50                25.0
# 2                      0.000            34.50                25.0
# 3                      0.000            34.50                25.0
# 4                      0.000            34.50                25.0
# ...                      ...              ...                 ...
# 2348240                0.425            43.25                 6.0
# 2348241                0.425            43.25                 6.0
# 2348242                0.425            43.25                 6.0
# 2348243                0.425            43.25                 6.0
# 2348244                0.000             6.00                21.0
#
#          Visibility (km)  Net Demand  Holiday  Day_Of_Week  Is_Weekend  Year  \
# 0                 16.100           0        1            2           0  2020
# 1                 16.100           2        1            2           0  2020
# 2                 16.100           0        1            2           0  2020
# 3                 16.100           1        1            2           0  2020
# 4                 16.100          -1        1            2           0  2020
# ...                  ...         ...      ...          ...         ...   ...
# 2348240           10.075           1        0            6           1  2020
# 2348241           10.075          -1        0            6           1  2020
# 2348242           10.075          -1        0            6           1  2020
# 2348243           10.075          -1        0            6           1  2020
# 2348244           16.100          -1        1            4           0  2021
#
#          Month Day of Month
# 0            1           01
# 1            1           01
# 2            1           01
# 3            1           01
# 4            1           01
# ...        ...          ...
# 2348240      3           29
# 2348241      3           29
# 2348242      3           29
# 2348243      3           29
# 2348244      1           01
#
# [2348245 rows x 20 columns]

# %% [markdown]
# ####Add ActiveTO Dates

# %%
ActiveTO_start_Date_2020 = pd.to_datetime('2020-05-23')
ActiveTO_end_Date_2020 = pd.to_datetime('2020-10-04')
ActiveTO_start_Date_2021_a = pd.to_datetime('2021-05-15')
ActiveTO_end_Date_2021_a = pd.to_datetime('2021-05-23')
ActiveTO_start_Date_2021_b = pd.to_datetime('2021-06-05')
ActiveTO_end_Date_2021_b = pd.to_datetime('2021-06-13')
ActiveTO_start_Date_2021_c = pd.to_datetime('2021-06-26')
ActiveTO_end_Date_2021_c = pd.to_datetime('2021-09-19')
ActiveTO_start_Date_2021_d = pd.to_datetime('2021-10-02')
ActiveTO_end_Date_2021_d = pd.to_datetime('2021-10-10')

# %%
df_full_net_demand['Active_TO'] = df_full_net_demand.apply(lambda row: 1 if ((row['Start_Date']>= ActiveTO_start_Date_2020) and (row['Start_Date'] <= ActiveTO_end_Date_2020) and (row['Is_Weekend'] == True)) else
                                                           ( 1 if ((row['Start_Date']>= ActiveTO_start_Date_2021_a) and (row['Start_Date'] <= ActiveTO_end_Date_2021_a) and (row['Is_Weekend'] == True)) else 
                                                            (   1 if ((row['Start_Date']>= ActiveTO_start_Date_2021_b) and (row['Start_Date'] <= ActiveTO_end_Date_2021_b) and (row['Is_Weekend'] == True)) else 
                                                            (   1 if ((row['Start_Date']>= ActiveTO_start_Date_2021_c) and (row['Start_Date'] <= ActiveTO_end_Date_2021_c) and (row['Is_Weekend'] == True)) else 
                                                            (   1 if ((row['Start_Date']>= ActiveTO_start_Date_2021_d) and (row['Start_Date'] <= ActiveTO_end_Date_2021_d) and (row['Is_Weekend'] == True)) else 0)))), axis = 1)

# %%
#check
df_full_net_demand[df_full_net_demand['Start_Date']>= ActiveTO_start_Date_2021_d]
# Out:
#          Start Station Id Start_Date Binned_Start_Time        lat        lon  \
# 1836800              7000 2021-10-02          10AM-2PM  43.639832 -79.395954
# 1836801              7000 2021-10-02          10AM-2PM  43.639832 -79.395954
# 1836802              7001 2021-10-02          10AM-2PM  43.664964 -79.383550
# 1836803              7001 2021-10-02          10AM-2PM  43.664964 -79.383550
# 1836804              7002 2021-10-02          10AM-2PM  43.667333 -79.399429
# ...                   ...        ...               ...        ...        ...
# 2348054              7627 2022-01-14           2AM-6AM  43.667076 -79.425116
# 2348055              7633 2022-01-14           2AM-6AM  43.642456 -79.429635
# 2348056              7634 2022-01-14           2AM-6AM  43.657845 -79.389927
# 2348057              7647 2022-01-14           2AM-6AM  43.656373 -79.387810
# 2348058              7667 2022-01-14           2AM-6AM  43.664028 -79.402979
#
#          capacity nearest_transit  POI_distance  Temp (°C)  \
# 1836800        35       St Andrew      1.249617      19.55
# 1836801        35       St Andrew      1.249617      19.55
# 1836802        17       Wellesley      0.065552      19.55
# 1836803        17       Wellesley      0.065552      19.55
# 1836804        19       St George      0.110642      19.55
# ...           ...             ...           ...        ...
# 2348054        15       Ossington      0.531854      -1.70
# 2348055        15        Dufferin      2.027020      -1.70
# 2348056        18    Queen's Park      0.230626      -1.70
# 2348057        17      St Patrick      0.176865      -1.70
# 2348058        35         Spadina      0.366572      -1.70
#
#          Precip. Amount (mm)  ...  Wind Dir (10s deg)  Visibility (km)  \
# 1836800                  0.0  ...               20.00             16.1
# 1836801                  0.0  ...               20.00             16.1
# 1836802                  0.0  ...               20.00             16.1
# 1836803                  0.0  ...               20.00             16.1
# 1836804                  0.0  ...               20.00             16.1
# ...                      ...  ...                 ...              ...
# 2348054                  0.0  ...               35.25             16.1
# 2348055                  0.0  ...               35.25             16.1
# 2348056                  0.0  ...               35.25             16.1
# 2348057                  0.0  ...               35.25             16.1
# 2348058                  0.0  ...               35.25             16.1
#
#          Net Demand  Holiday  Day_Of_Week  Is_Weekend  Year  Month  \
# 1836800           5        0            5           1  2021     10
# 1836801           9        0            5           1  2021     10
# 1836802           0        0            5           1  2021     10
# 1836803           0        0            5           1  2021     10
# 1836804          -1        0            5           1  2021     10
# ...             ...      ...          ...         ...   ...    ...
# 2348054           0        0            4           0  2022      1
# 2348055           2        0            4           0  2022      1
# 2348056           0        0            4           0  2022      1
# 2348057          -2        0            4           0  2022      1
# 2348058          -4        0            4           0  2022      1
#
#          Day of Month Active_TO
# 1836800            02         1
# 1836801            02         1
# 1836802            02         1
# 1836803            02         1
# 1836804            02         1
# ...               ...       ...
# 2348054            14         0
# 2348055            14         0
# 2348056            14         0
# 2348057            14         0
# 2348058            14         0
#
# [439415 rows x 21 columns]

# %% [markdown]
# ####Add Lockdown Dates

# %%
Lockdown_start_Date_2020_a = pd.to_datetime('2020-03-17')
Lockdown_end_Date_2020_a = pd.to_datetime('2020-06-24')
Lockdown_start_Date_2020_b = pd.to_datetime('2020-11-23')
Lockdown_end_Date_2020_b = pd.to_datetime('2021-03-08')
Lockdown_start_Date_2021_a = pd.to_datetime('2021-04-04')
Lockdown_end_Date_2021_a = pd.to_datetime('2021-06-02')
Lockdown_start_Date_2021_b = pd.to_datetime('2021-04-04')
Lockdown_end_Date_2021_b = pd.to_datetime('2021-06-02')

# %%
df_full_net_demand['Lockdown_Stay_at_Home'] = df_full_net_demand.apply(lambda row: 1 if ((row['Start_Date']>= Lockdown_start_Date_2020_a) and (row['Start_Date'] <= Lockdown_end_Date_2020_a)) else
                                                           ( 1 if ((row['Start_Date']>= Lockdown_start_Date_2020_b) and (row['Start_Date'] <= Lockdown_end_Date_2020_b)) else 
                                                            (   1 if ((row['Start_Date']>= Lockdown_start_Date_2021_a) and (row['Start_Date'] <= Lockdown_end_Date_2021_a)) else 
                                                            (   1 if ((row['Start_Date']>= Lockdown_start_Date_2021_b) and (row['Start_Date'] <= Lockdown_end_Date_2021_b)) else 0))), axis = 1)

# %%
df_full_net_demand.sort_values(by = 'Start_Date', inplace = True)

# %% [markdown]
# ###Drop Unnecessary Columns

# %%
df_full_net_demand.drop(['lat','lon','Start_Date'],axis = 1, inplace = True)

# %%
df_full_net_demand.drop(['Day_Of_Week'],axis = 1, inplace = True)

# %%
df_full_net_demand
# Out:
#          Start Station Id Binned_Start_Time  capacity  nearest_transit  \
# 0                    7000          10AM-2PM        35        St Andrew
# 831                  7089          6PM-10PM        19  College Station
# 830                  7088          6PM-10PM        15          Coxwell
# 829                  7085          6PM-10PM        15      Main Street
# 828                  7078          6PM-10PM        11     Queen's Park
# ...                   ...               ...       ...              ...
# 2240806              7147           2PM-6PM        15    Exhibition GO
# 2240807              7148           2PM-6PM        15    Exhibition GO
# 2240808              7149           2PM-6PM        11         Christie
# 2240790              7130           2PM-6PM        15           Dupont
# 2240831              7164           2PM-6PM        22           Dundas
#
#          POI_distance  Temp (°C)  Precip. Amount (mm)  Wind Spd (km/h)  \
# 0            1.249617      0.250                  0.0            34.50
# 831          0.298138     -0.375                  0.0            25.75
# 830          0.092819     -0.375                  0.0            25.75
# 829          0.300037     -0.375                  0.0            25.75
# 828          1.054467     -0.375                  0.0            25.75
# ...               ...        ...                  ...              ...
# 2240806      0.657338     -6.100                  0.0            13.50
# 2240807      0.556183     -6.100                  0.0            13.50
# 2240808      0.683979     -6.100                  0.0            13.50
# 2240790      0.679146     -6.100                  0.0            13.50
# 2240831      0.134834     -6.100                  0.0            13.50
#
#          Wind Dir (10s deg)  Visibility (km)  Net Demand  Holiday  Is_Weekend  \
# 0                     25.00             16.1           0        1           0
# 831                   23.50             16.1           2        1           0
# 830                   23.50             16.1          -2        1           0
# 829                   23.50             16.1           2        1           0
# 828                   23.50             16.1          -4        1           0
# ...                     ...              ...         ...      ...         ...
# 2240806               10.25             16.1          -2        0           0
# 2240807               10.25             16.1           2        0           0
# 2240808               10.25             16.1          -4        0           0
# 2240790               10.25             16.1           6        0           0
# 2240831               10.25             16.1           0        0           0
#
#          Year  Month Day of Month  Active_TO  Lockdown_Stay_at_Home
# 0        2020      1           01          0                      0
# 831      2020      1           01          0                      0
# 830      2020      1           01          0                      0
# 829      2020      1           01          0                      0
# 828      2020      1           01          0                      0
# ...       ...    ...          ...        ...                    ...
# 2240806  2022      2           28          0                      0
# 2240807  2022      2           28          0                      0
# 2240808  2022      2           28          0                      0
# 2240790  2022      2           28          0                      0
# 2240831  2022      2           28          0                      0
#
# [2348245 rows x 18 columns]

# %% [markdown]
# ### Add Station Classification

# %% [markdown]
# ##### Drop 0 Net Change Lines

# %%
df_full_non_zero_net_demand_trim = df_full_net_demand[df_full_net_demand['Net Demand']!=0]

# %%
df_full_non_zero_net_demand_trim
# Out:
#          Start Station Id Binned_Start_Time  capacity  nearest_transit  \
# 831                  7089          6PM-10PM        19  College Station
# 830                  7088          6PM-10PM        15          Coxwell
# 829                  7085          6PM-10PM        15      Main Street
# 828                  7078          6PM-10PM        11     Queen's Park
# 827                  7077          6PM-10PM        19  College Station
# ...                   ...               ...       ...              ...
# 2240805              7144           2PM-6PM        15         Bathurst
# 2240806              7147           2PM-6PM        15    Exhibition GO
# 2240807              7148           2PM-6PM        15    Exhibition GO
# 2240808              7149           2PM-6PM        11         Christie
# 2240790              7130           2PM-6PM        15           Dupont
#
#          POI_distance  Temp (°C)  Precip. Amount (mm)  Wind Spd (km/h)  \
# 831          0.298138     -0.375                  0.0            25.75
# 830          0.092819     -0.375                  0.0            25.75
# 829          0.300037     -0.375                  0.0            25.75
# 828          1.054467     -0.375                  0.0            25.75
# 827          0.173866     -0.375                  0.0            25.75
# ...               ...        ...                  ...              ...
# 2240805      0.729453     -6.100                  0.0            13.50
# 2240806      0.657338     -6.100                  0.0            13.50
# 2240807      0.556183     -6.100                  0.0            13.50
# 2240808      0.683979     -6.100                  0.0            13.50
# 2240790      0.679146     -6.100                  0.0            13.50
#
#          Wind Dir (10s deg)  Visibility (km)  Net Demand  Holiday  Is_Weekend  \
# 831                   23.50             16.1           2        1           0
# 830                   23.50             16.1          -2        1           0
# 829                   23.50             16.1           2        1           0
# 828                   23.50             16.1          -4        1           0
# 827                   23.50             16.1           1        1           0
# ...                     ...              ...         ...      ...         ...
# 2240805               10.25             16.1           2        0           0
# 2240806               10.25             16.1          -2        0           0
# 2240807               10.25             16.1           2        0           0
# 2240808               10.25             16.1          -4        0           0
# 2240790               10.25             16.1           6        0           0
#
#          Year  Month Day of Month  Active_TO  Lockdown_Stay_at_Home
# 831      2020      1           01          0                      0
# 830      2020      1           01          0                      0
# 829      2020      1           01          0                      0
# 828      2020      1           01          0                      0
# 827      2020      1           01          0                      0
# ...       ...    ...          ...        ...                    ...
# 2240805  2022      2           28          0                      0
# 2240806  2022      2           28          0                      0
# 2240807  2022      2           28          0                      0
# 2240808  2022      2           28          0                      0
# 2240790  2022      2           28          0                      0
#
# [1912438 rows x 18 columns]

# %% [markdown]
# ##### Classification Column

# %%
df_full_non_zero_net_demand_trim['Positive Net Demand'] = df_full_non_zero_net_demand_trim['Net Demand'].apply( lambda row: 1 if (row>= 0) else 0 )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_full_non_zero_net_demand_trim = df_full_non_zero_net_demand_trim.drop(columns = 'Net Demand')

# %% [markdown]
# ### Save Full Feature Dataset

# %%
df_full_non_zero_net_demand_trim.to_csv('../data/final_trip_feature_data.csv', index=False)

# %% [markdown]
# ## EDA
# Do the following
#
# 1. Split dataframe into numerical and cateogircal features
# 2. Do correlation analysis on numerical features
# 3. If some are more important (numerical) - focus on higher correlation features

# %% [markdown]
# ### Load Final Trip and Feature Dataset

# %%
## TODO: Fix this reference
data_path = "../data/final_trip_feature_data.csv"
df_full_net_demand = pd.read_csv(data_path)
df_full_net_demand
# Out:
#          Start Station Id Binned_Start_Time  capacity  nearest_transit  \
# 0                    7089          6PM-10PM        19  College Station
# 1                    7088          6PM-10PM        15          Coxwell
# 2                    7085          6PM-10PM        15      Main Street
# 3                    7078          6PM-10PM        11     Queen's Park
# 4                    7077          6PM-10PM        19  College Station
# ...                   ...               ...       ...              ...
# 1912433              7144           2PM-6PM        15         Bathurst
# 1912434              7147           2PM-6PM        15    Exhibition GO
# 1912435              7148           2PM-6PM        15    Exhibition GO
# 1912436              7149           2PM-6PM        11         Christie
# 1912437              7130           2PM-6PM        15           Dupont
#
#          POI_distance  Temp (°C)  Precip. Amount (mm)  Wind Spd (km/h)  \
# 0            0.298138     -0.375                  0.0            25.75
# 1            0.092819     -0.375                  0.0            25.75
# 2            0.300037     -0.375                  0.0            25.75
# 3            1.054467     -0.375                  0.0            25.75
# 4            0.173866     -0.375                  0.0            25.75
# ...               ...        ...                  ...              ...
# 1912433      0.729453     -6.100                  0.0            13.50
# 1912434      0.657338     -6.100                  0.0            13.50
# 1912435      0.556183     -6.100                  0.0            13.50
# 1912436      0.683979     -6.100                  0.0            13.50
# 1912437      0.679146     -6.100                  0.0            13.50
#
#          Wind Dir (10s deg)  Visibility (km)  Holiday  Is_Weekend  Year  \
# 0                     23.50             16.1        1           0  2020
# 1                     23.50             16.1        1           0  2020
# 2                     23.50             16.1        1           0  2020
# 3                     23.50             16.1        1           0  2020
# 4                     23.50             16.1        1           0  2020
# ...                     ...              ...      ...         ...   ...
# 1912433               10.25             16.1        0           0  2022
# 1912434               10.25             16.1        0           0  2022
# 1912435               10.25             16.1        0           0  2022
# 1912436               10.25             16.1        0           0  2022
# 1912437               10.25             16.1        0           0  2022
#
#          Month  Day of Month  Active_TO  Lockdown_Stay_at_Home  \
# 0            1             1          0                      0
# 1            1             1          0                      0
# 2            1             1          0                      0
# 3            1             1          0                      0
# 4            1             1          0                      0
# ...        ...           ...        ...                    ...
# 1912433      2            28          0                      0
# 1912434      2            28          0                      0
# 1912435      2            28          0                      0
# 1912436      2            28          0                      0
# 1912437      2            28          0                      0
#
#          Positive Net Demand
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          1
# ...                      ...
# 1912433                    1
# 1912434                    0
# 1912435                    1
# 1912436                    0
# 1912437                    1
#
# [1912438 rows x 18 columns]

# %%
df =  df_full_net_demand.rename(columns={"Start Station Id" : "Station Id",
    "Binned_Start_Time" : "Time",
    "capacity" : "Station Capacity",
    "nearest_transit" : "Nearest Transit Station Name",
    "POI_distance" : "Distance to Nearest Transit Station",
    "Is_Weekend" : "Weekend",
    "Active_TO" : "Active TO",
    "Lockdown_Stay_at_Home" : "Lockdown"
})

# %%
df.head(10)
# Out:
#    Station Id      Time  Station Capacity Nearest Transit Station Name  \
# 0        7089  6PM-10PM                19              College Station
# 1        7088  6PM-10PM                15                      Coxwell
# 2        7085  6PM-10PM                15                  Main Street
# 3        7078  6PM-10PM                11                 Queen's Park
# 4        7077  6PM-10PM                19              College Station
# 5        7077  6PM-10PM                19              College Station
# 6        7076  6PM-10PM                57                Union Station
# 7        7076  6PM-10PM                57                Union Station
# 8        7073  6PM-10PM                23                    St Andrew
# 9        7072  6PM-10PM                19                    St Andrew
#
#    Distance to Nearest Transit Station  Temp (°C)  Precip. Amount (mm)  \
# 0                             0.298138     -0.375                  0.0
# 1                             0.092819     -0.375                  0.0
# 2                             0.300037     -0.375                  0.0
# 3                             1.054467     -0.375                  0.0
# 4                             0.173866     -0.375                  0.0
# 5                             0.173866     -0.375                  0.0
# 6                             0.566016     -0.375                  0.0
# 7                             0.566016     -0.375                  0.0
# 8                             1.079306     -0.375                  0.0
# 9                             1.735353     -0.375                  0.0
#
#    Wind Spd (km/h)  Wind Dir (10s deg)  Visibility (km)  Holiday  Weekend  \
# 0            25.75                23.5             16.1        1        0
# 1            25.75                23.5             16.1        1        0
# 2            25.75                23.5             16.1        1        0
# 3            25.75                23.5             16.1        1        0
# 4            25.75                23.5             16.1        1        0
# 5            25.75                23.5             16.1        1        0
# 6            25.75                23.5             16.1        1        0
# 7            25.75                23.5             16.1        1        0
# 8            25.75                23.5             16.1        1        0
# 9            25.75                23.5             16.1        1        0
#
#    Year  Month  Day of Month  Active TO  Lockdown  Positive Net Demand
# 0  2020      1             1          0         0                    1
# 1  2020      1             1          0         0                    0
# 2  2020      1             1          0         0                    1
# 3  2020      1             1          0         0                    0
# 4  2020      1             1          0         0                    1
# 5  2020      1             1          0         0                    0
# 6  2020      1             1          0         0                    0
# 7  2020      1             1          0         0                    0
# 8  2020      1             1          0         0                    1
# 9  2020      1             1          0         0                    0

# %% [markdown]
# ### Split Into Numerical and Categorical Features

# %%
df.columns
# Out:
# Index(['Station Id', 'Time', 'Station Capacity',
#        'Nearest Transit Station Name', 'Distance to Nearest Transit Station',
#        'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)',
#        'Wind Dir (10s deg)', 'Visibility (km)', 'Holiday', 'Weekend', 'Year',
#        'Month', 'Day of Month', 'Active TO', 'Lockdown',
#        'Positive Net Demand'],
#       dtype='object')

# %%
num_features = ['Station Capacity',
       'Distance to Nearest Transit Station',
       'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)',
       'Wind Dir (10s deg)', 'Visibility (km)', 'Positive Net Demand']
cat_features = ['Station Id', 'Time', 'Nearest Transit Station Name',
       'Holiday','Weekend', 'Year', 'Month', 'Day of Month', 'Active TO', 
       'Lockdown']

# %%
df_num = df[num_features]

# %% [markdown]
# ### Bar Plot Analysis

# %%
df.hist(figsize=(18,18), color = '#137053');

# %% [markdown]
# ### Numerical Feature Summary Statistics

# %%
df.describe()
# Out:
#          Station Id  Station Capacity  Distance to Nearest Transit Station  \
# count  1.912438e+06      1.912438e+06                         1.912438e+06
# mean   7.274492e+03      1.922102e+01                         8.346906e-01
# std    1.831887e+02      6.876472e+00                         7.692055e-01
# min    7.000000e+03      7.000000e+00                         1.352040e-02
# 25%    7.113000e+03      1.500000e+01                         2.490548e-01
# 50%    7.258000e+03      1.900000e+01                         5.884515e-01
# 75%    7.418000e+03      2.300000e+01                         1.227995e+00
# max    7.681000e+03      5.700000e+01                         5.545345e+00
#
#           Temp (°C)  Precip. Amount (mm)  Wind Spd (km/h)  Wind Dir (10s deg)  \
# count  1.912438e+06         1.912438e+06     1.912438e+06        1.912438e+06
# mean   1.295452e+01         6.196385e-02     1.623261e+01        1.973778e+01
# std    9.307706e+00         3.499213e-01     8.137152e+00        8.616382e+00
# min   -1.952500e+01         0.000000e+00     0.000000e+00        1.750000e+00
# 25%    5.550000e+00         0.000000e+00     1.025000e+01        1.150000e+01
# 50%    1.450000e+01         0.000000e+00     1.475000e+01        2.100000e+01
# 75%    2.067500e+01         0.000000e+00     2.075000e+01        2.675000e+01
# max    3.270000e+01         5.625000e+00     5.650000e+01        3.600000e+01
#
#        Visibility (km)       Holiday       Weekend          Year  \
# count     1.912438e+06  1.912438e+06  1.912438e+06  1.912438e+06
# mean      1.550906e+01  2.636791e-02  2.931081e-01  2.020606e+03
# std       1.950352e+00  1.602269e-01  4.551877e-01  5.736519e-01
# min       3.500000e-01  0.000000e+00  0.000000e+00  2.020000e+03
# 25%       1.610000e+01  0.000000e+00  0.000000e+00  2.020000e+03
# 50%       1.610000e+01  0.000000e+00  0.000000e+00  2.021000e+03
# 75%       1.610000e+01  0.000000e+00  1.000000e+00  2.021000e+03
# max       1.610000e+01  1.000000e+00  1.000000e+00  2.022000e+03
#
#               Month  Day of Month     Active TO      Lockdown  \
# count  1.912438e+06  1.912438e+06  1.912438e+06  1.912438e+06
# mean   7.121290e+00  1.564772e+01  1.491154e-01  2.388909e-01
# std    3.075229e+00  8.766458e+00  3.562023e-01  4.264061e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.000000e+00  8.000000e+00  0.000000e+00  0.000000e+00
# 50%    7.000000e+00  1.600000e+01  0.000000e+00  0.000000e+00
# 75%    1.000000e+01  2.300000e+01  0.000000e+00  0.000000e+00
# max    1.200000e+01  3.100000e+01  1.000000e+00  1.000000e+00
#
#        Positive Net Demand
# count         1.912438e+06
# mean          5.082983e-01
# std           4.999313e-01
# min           0.000000e+00
# 25%           0.000000e+00
# 50%           1.000000e+00
# 75%           1.000000e+00
# max           1.000000e+00

# %% [markdown]
# ### Categorical Feature Summary Statistics

# %%
df.describe(include='object')
# Out:
#            Time Nearest Transit Station Name
# count   1912438                      1912438
# unique        6                           60
# top     2PM-6PM                         King
# freq     456973                       144656

# %% [markdown]
# ### Box Plots - Numerical

# %%
num_cols = ['Station Capacity',
       'Distance to Nearest Transit Station',
       'Month', 'Day of Month',
       'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)',
       'Wind Dir (10s deg)', 'Visibility (km)']
colors = ['#137053', '#2eb459']
sns.set_palette(colors)
for col in num_cols:
    sns.boxplot(y = df['Positive Net Demand'].astype('category'), x = col , data=df)
    plt.show()

# %%
num_cols = ['Station Capacity',
       'Distance to Nearest Transit Station',
       'Month', 'Day of Month',
       'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)',
       'Wind Dir (10s deg)', 'Visibility (km)']
for col in num_cols:
    sns.boxplot(y = df['Positive Net Demand'].astype('category'), x = col , data=df)
    plt.show()

# %% [markdown]
# ### Positive Net Demand vs Categorical Features

# %%
g = sns.catplot(x = 'Time', kind='count', 
                col = 'Positive Net Demand', data=df, sharey=False,
                order = ['10PM-2AM','2AM-6AM','6AM-10AM', '10AM-2PM','2PM-6PM','6PM-10PM'],
                height=5, aspect=2
                )
g.set_xticklabels(rotation=60);

# %%
g = sns.catplot(x = 'Nearest Transit Station Name', kind='count', 
                col = 'Positive Net Demand', data=df, sharey=True,
                height=5, aspect=2
                )
g.set_xticklabels(rotation=90);

# %% [markdown]
# ### Heatmap Correlation

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.sample(1000).corr(), cmap='RdBu_r', annot=True, vmax=1, vmin=-1)
plt.show()

# %%
df['Positive Net Demand'] = df['Positive Net Demand'].apply( lambda row: 1 if (row>= 0) else 0 )

# %%
colors = {1:'green', 0: 'red'}
plt.figure(figsize=(10, 10), dpi=80)
plt.scatter(df['Distance to Nearest Transit Station'], 
            df['Temp (°C)'], 
            c=df['Positive Net Demand'].map(colors),
            )
plt.title('Positive Net - Temperature vs Distance to Transit')
plt.xlabel('Distance to Nearest Transit Station (km)')
plt.ylabel('Temperature (°C)')
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %%
colors = {1:'green', 0: 'red'}
plt.figure(figsize=(10, 10), dpi=80)
plt.scatter(
            df['Time'], 
            df['Distance to Nearest Transit Station'], 
            c=df['Positive Net Demand'].map(colors),
            )
plt.title('Positive Net - Temperature vs Distance to Transit')
plt.xlabel('Time')
plt.ylabel('Distance to Nearest Transit Station')
# Out:
# Text(0, 0.5, 'Distance to Nearest Transit Station')

# %%
df_full_non_zero_net_demand_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1912438 entries, 831 to 2240790
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Start Station Id       int64
#  1   Binned_Start_Time      object
#  2   capacity               int64
#  3   nearest_transit        object
#  4   POI_distance           float64
#  5   Temp (°C)              float64
#  6   Precip. Amount (mm)    float64
#  7   Wind Spd (km/h)        float64
#  8   Wind Dir (10s deg)     float64
#  9   Visibility (km)        float64
#  10  Holiday                int64
#  11  Is_Weekend             int64
#  12  Year                   int64
#  13  Month                  int64
#  14  Day of Month           object
#  15  Active_TO              int64
#  16  Lockdown_Stay_at_Home  int64
#  17  Positive Net Demand    int64
# dtypes: float64(6), int64(9), object(3)
# memory usage: 277.2+ MB
